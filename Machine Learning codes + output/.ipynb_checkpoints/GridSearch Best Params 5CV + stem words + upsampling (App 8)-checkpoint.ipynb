# %% [markdown]
# # 3 Class 5CV LR_SVC_MNB_DT Words Stem + UpSampling (App 6)

# %% [markdown]
# ## 1) Import Packages

# %%
### BASIC PACKAGES
import pandas as pd
import numpy as np

### SKLEARN'S MACHINE LEARNING MODELS
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz

### METRICS CALCULATION
from sklearn import metrics

### SPACY'S STOP WORDS
from spacy.lang.en.stop_words import STOP_WORDS

### NLTK STEMMER
from nltk.stem.snowball import SnowballStemmer

### VISUALIZATION
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
new_stop_words = list(STOP_WORDS)
new_stop_words.append("buy")
print(sorted(new_stop_words))
# Out:
# ['a', 'about', 'above', 'across', 'after', 'afterwards', 'again', 'against', 'all', 'almost', 'alone', 'along', 'already', 'also', 'although', 'always', 'am', 'among', 'amongst', 'amount', 'an', 'and', 'another', 'any', 'anyhow', 'anyone', 'anything', 'anyway', 'anywhere', 'are', 'around', 'as', 'at', 'back', 'be', 'became', 'because', 'become', 'becomes', 'becoming', 'been', 'before', 'beforehand', 'behind', 'being', 'below', 'beside', 'besides', 'between', 'beyond', 'both', 'bottom', 'but', 'buy', 'by', 'ca', 'call', 'can', 'cannot', 'could', 'did', 'do', 'does', 'doing', 'done', 'down', 'due', 'during', 'each', 'eight', 'either', 'eleven', 'else', 'elsewhere', 'empty', 'enough', 'even', 'ever', 'every', 'everyone', 'everything', 'everywhere', 'except', 'few', 'fifteen', 'fifty', 'first', 'five', 'for', 'former', 'formerly', 'forty', 'four', 'from', 'front', 'full', 'further', 'get', 'give', 'go', 'had', 'has', 'have', 'he', 'hence', 'her', 'here', 'hereafter', 'hereby', 'herein', 'hereupon', 'hers', 'herself', 'him', 'himself', 'his', 'how', 'however', 'hundred', 'i', 'if', 'in', 'indeed', 'into', 'is', 'it', 'its', 'itself', 'just', 'keep', 'last', 'latter', 'latterly', 'least', 'less', 'made', 'make', 'many', 'may', 'me', 'meanwhile', 'might', 'mine', 'more', 'moreover', 'most', 'mostly', 'move', 'much', 'must', 'my', 'myself', 'name', 'namely', 'neither', 'never', 'nevertheless', 'next', 'nine', 'no', 'nobody', 'none', 'noone', 'nor', 'not', 'nothing', 'now', 'nowhere', 'of', 'off', 'often', 'on', 'once', 'one', 'only', 'onto', 'or', 'other', 'others', 'otherwise', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 'part', 'per', 'perhaps', 'please', 'put', 'quite', 'rather', 're', 'really', 'regarding', 'same', 'say', 'see', 'seem', 'seemed', 'seeming', 'seems', 'serious', 'several', 'she', 'should', 'show', 'side', 'since', 'six', 'sixty', 'so', 'some', 'somehow', 'someone', 'something', 'sometime', 'sometimes', 'somewhere', 'still', 'such', 'take', 'ten', 'than', 'that', 'the', 'their', 'them', 'themselves', 'then', 'thence', 'there', 'thereafter', 'thereby', 'therefore', 'therein', 'thereupon', 'these', 'they', 'third', 'this', 'those', 'though', 'three', 'through', 'throughout', 'thru', 'thus', 'to', 'together', 'too', 'top', 'toward', 'towards', 'twelve', 'twenty', 'two', 'under', 'unless', 'until', 'up', 'upon', 'us', 'used', 'using', 'various', 'very', 'via', 'was', 'we', 'well', 'were', 'what', 'whatever', 'when', 'whence', 'whenever', 'where', 'whereafter', 'whereas', 'whereby', 'wherein', 'whereupon', 'wherever', 'whether', 'which', 'while', 'whither', 'who', 'whoever', 'whole', 'whom', 'whose', 'why', 'will', 'with', 'within', 'without', 'would', 'yet', 'you', 'your', 'yours', 'yourself', 'yourselves']

# %% [markdown]
# ## 2) ML with CV

# %%
# Pre-Processing:
# X = X or predictor variables, 1-D list or np.array
# y = y or target variables, 1-D list or np.array
# vect = CountVectorizer Text Preprocessor, needed for Text Analysis Machine Learning Model, CountVectorizer
# model = Machine Learning Model (E.g. Multinomial Naive Bayes, Linear SVC, LogisticRegression), sklearn ml model
# n_runs = Number of Runs to execute, int
# split_size = K fold Cross Validation, int
# print_itr = condition to print the iterations 

# Post-Processing:
# index = Index Labels of the data in the form of iter{iteration int}_cv_split{cv_split int}, list of int
# full_buy_words = list of lists of top 10 words in predicting label: "Buy", list of list of str
# full_sell_words = list of lists of top 10 words in predicting label: "Sell", list of list of str
# full_train_aucs = List of Areas Under Curve in predicting Training set data, list of float
# full_test_aucs = List of Areas Under Curve in predicting Testing set data, list of float
# full_train_accs = List of Accuracy Scores in predicting Training set data, list of float
# full_test_accs = List of Accuracy Scores in predicting Testing set data, list of float
# full_train_null_accs = List of Null Accuracy Scores in predicting Training set data, list of float
# full_test_null_accs = List of Null Accuracy Scores in predicting Testing set data, list of float
# full_test_conf_mats = Array of Confusion Matrix under the Test set, Numpy Array
# full_train_conf_mats = Array of Confusion Matrix under the Train set, Numpy Array

def ml_cv(X, y, vect, model, n_runs, split_size, print_itr):
    
    n_rows = len(y)

    ### RESULTS LISTS ###
    full_buy_words = []
    full_neut_words = []
    full_sell_words = []

    full_train_accs = []
    full_test_accs = []

    #full_train_aucs = []
    #full_test_aucs = []
    
    full_train_null_accs = []
    full_test_null_accs = []
    
    full_train_conf_mats = []
    full_test_conf_mats = []
    
    index = []
    
    classes = sorted(list(set(y)))
    
    class_pos_dict = {}
    all_pos_classes = []
    for c, ind in zip(classes, range(len(classes))):
        all_pos_classes.append([a for a in range(len(y)) if y[a] == c])
        class_pos_dict[c] = ind

    all_cv_splits_classes = []
    for c, all_pos_c in zip(classes, all_pos_classes):
        cv_splits_curr_c = [len(split_amts) for split_amts in np.array_split(list(range(len(all_pos_c))), split_size)]
        all_cv_splits_classes.append(cv_splits_curr_c)
    
    for i in range(n_runs):
        if(print_itr):
            print("Run: {curr_run} out of {n_runs}".format(curr_run = i+1, n_runs = n_runs))
        
        all_pos = range(len(y))
        
        all_cv_set_pos_classes = []
        for c in classes:
            all_cv_set_pos_classes.append([a for a in range(len(y)) if y[a] == c])
        
        for cv in range(split_size):
            if(print_itr):
                print("Cross Validation: {curr_split} out of {split_size}".format(curr_split = cv + 1, split_size = split_size))
            
            test_pos = []
            
            if cv == split_size - 1:
                for ls in all_cv_set_pos_classes:
                    test_pos = test_pos + ls
            else:
                all_test_pos_classes = []
                for c in classes:
                    all_test_pos_classes.append(list(np.random.choice(all_cv_set_pos_classes[class_pos_dict[c]], 
                                                                      size = all_cv_splits_classes[class_pos_dict[c]][cv], 
                                                                      replace=False)))
                for ls in all_test_pos_classes:
                    test_pos = test_pos + ls

            train_pos = list(set(all_pos) - set(test_pos))
            
            #print("train: ", train_pos, len(train_pos))
            #print("test: ", test_pos, len(test_pos))
            #print("Everything", list(set(train_pos + test_pos)), len(list(set(train_pos + test_pos))))
            
            X_train = [X[a] for a in train_pos]
            X_test = [X[a] for a in test_pos]
            y_train = [y[a] for a in train_pos]
            y_test = [y[a] for a in test_pos]
            
            update_cv_set_pos_classes = []
            for cv_ls, test_ls in zip(all_cv_set_pos_classes, all_test_pos_classes):
                update_cv_set_pos_classes.append(list(set(cv_ls) - set(test_ls)))
            #cv_set_pos_c0 = list(set(cv_set_pos_c0) - set(test_pos_c0))
            #cv_set_pos_c1 = list(set(cv_set_pos_c1) - set(test_pos_c1))
            
            all_cv_set_pos_classes = update_cv_set_pos_classes
            
            X_train_dtm = vect.fit_transform(X_train)
            X_test_dtm = vect.transform(X_test)

            model.fit(X_train_dtm, y_train)
            
            # PREDICTION ACCURACY SCORES
            y_pred_test_class = model.predict(X_test_dtm)
            y_pred_train_class = model.predict(X_train_dtm)
            
            train_acc_score = metrics.accuracy_score(y_pred=y_pred_train_class, y_true=y_train)
            test_acc_score = metrics.accuracy_score(y_pred=y_pred_test_class, y_true=y_test)
            
            full_train_accs.append(train_acc_score)
            full_test_accs.append(test_acc_score)
            
            # CONFUSION MATRIX
            full_train_conf_mats.append(metrics.confusion_matrix(y_true = y_train, y_pred = y_pred_train_class, labels = classes))
            full_test_conf_mats.append(metrics.confusion_matrix(y_true = y_test, y_pred = y_pred_test_class, labels = classes))
            
            # NULL ACCURACY SCORES
            train_classes = list(np.unique(y_train))
            test_classes = list(np.unique(y_test))
            
            train_most_occur_class = train_classes[1] if len([a for a in y_train if a == train_classes[1]])/len(y_train) >= 0.5 else train_classes[0]
            test_most_occur_class = test_classes[1] if len([a for a in y_test if a == test_classes[1]])/len(y_test) >= 0.5 else test_classes[0]
            
            train_null_acc = sum([1 for a in y_train if a == train_most_occur_class])/len(y_train)
            test_null_acc = sum([1 for a in y_test if a == test_most_occur_class])/len(y_test)
            
            full_train_null_accs.append(train_null_acc)
            full_test_null_accs.append(test_null_acc)
            
            # TOP 10 SELL, NEUTRAL AND BUY WORD PREDICTORS
            if 'coef_' in dir(model):
                #df = pd.DataFrame({'coef': model.coef_[0], 'word': vect.get_feature_names()})
                max_pos = [np.argmax(a) for a in model.coef_.transpose()]
                top_words_dicts = []
                for c in classes:
                    top_words_dicts.append({'coef': [], 'word': []})

                for coef_ls, word in zip(model.coef_.transpose(), vect.get_feature_names()):
                    top_words_dicts[np.argmax(coef_ls)]['coef'].append(np.max(coef_ls))
                    top_words_dicts[np.argmax(coef_ls)]['word'].append(word)
                
            elif 'feature_importances_' in dir(model):
                df = pd.DataFrame({'coef': model.feature_importances_, 'word': vect.get_feature_names()})
                
            
            sell_words_df = pd.DataFrame(top_words_dicts[0]).sort_values('coef', ascending=False)
            neut_words_df = pd.DataFrame(top_words_dicts[1]).sort_values('coef', ascending=False)
            buy_words_df = pd.DataFrame(top_words_dicts[2]).sort_values('coef', ascending=False)
            
            sell_words = list(sell_words_df.word[:10])
            neut_words = list(neut_words_df.word[:10])
            buy_words = list(buy_words_df.word[:10])

            full_sell_words.append(sell_words)
            full_neut_words.append(neut_words)
            full_buy_words.append(buy_words)
            
            # ITERATION AND SPLIT AS INDEXES
            curr_index = "iter{itr}_cv_split{cv_split}".format(itr = i + 1, cv_split = cv + 1)
            index.append(curr_index)
            
    return index, full_sell_words, full_neut_words, full_buy_words, full_train_accs, full_test_accs, full_test_null_accs, full_train_null_accs, full_test_conf_mats, full_train_conf_mats

# %% [markdown]
# ## 3) Stem All Tweets

# %%
### READ ALL TWEETS DATA
all_tweets = pd.read_csv('all_tweets_data.csv')

### STEM ALL TWEETS
stemmer = SnowballStemmer("english")
new_tweets_stem = []
for twt in all_tweets['new_tweets']:
    stem_words = [stemmer.stem(word) for word in twt.split(" ")]
    new_sentence = stem_words[0]
    for word in stem_words[1:]:
        new_sentence = new_sentence + " " + word
    new_tweets_stem.append(new_sentence)

### ADD NEWLY STEMMED TWEETS TO DF
all_tweets['new_tweets_stem'] = pd.Series(new_tweets_stem)
all_tweets
# Out:
#          X  Buy/Neutral/Sell  \
# 0        1                 0
# 1        2                 0
# 2        3                 0
# 3        5                 1
# 4        6                 1
# 5        8                 0
# 6        9                 0
# 7       11                 0
# 8       14                 0
# 9       16                 1
# 10      17                 0
# 11      18                 0
# 12      19                 1
# 13      20                 0
# 14      25                 0
# 15      27                 0
# 16      28                 0
# 17      30                 0
# 18      31                 0
# 19      33                 0
# 20      34                 0
# 21      36                 0
# 22      43                 1
# 23      44                 0
# 24      45                 0
# 25      47                 0
# 26      49                 1
# 27      51                 0
# 28      52                 0
# 29      54                 0
# ...    ...               ...
# 1907  3614                 0
# 1908  3615                 1
# 1909  3616                 1
# 1910  3617                 1
# 1911  3623                 1
# 1912  3624                -1
# 1913  3625                 0
# 1914  3626                 0
# 1915  3627                 0
# 1916  3631                 0
# 1917  3632                 0
# 1918  3633                 0
# 1919  3635                 0
# 1920  3637                 1
# 1921  3639                 0
# 1922  3640                 0
# 1923  3641                 0
# 1924  3642                 0
# 1925  3643                 0
# 1926  3644                 1
# 1927  3646                 0
# 1928  3647                 0
# 1929  3649                 0
# 1930  3650                 0
# 1931  3651                 0
# 1932  3652                 0
# 1933  3654                 0
# 1934  3655                 1
# 1935  3656                 1
# 1936  3657                 1
#
#                                                  tweets  replies  retweets  \
# 0     <a href="/hashtag/Substratum?src=hash" data-qu...     88.0     376.0
# 1     <a href="https://t.co/WLJYQmRqOK" rel="nofollo...    156.0      72.0
# 2     Looking for a woman with ex SOF military exper...    416.0     206.0
# 3     Coin Brothers - "Buy the Fucking Dip"\n\n<a hr...    296.0     401.0
# 4     Lot's of people asking me over the past two da...    984.0    2100.0
# 5     Call for White papers: There are more than 50 ...    320.0     203.0
# 6     We are in a revolution against the waning powe...   1400.0    6400.0
# 7     Freelancers are 35% of the workforce. <a href=...    222.0     139.0
# 8     John McAfee Group Buy T-Shirt\n\n18,90 $ ! EU ...     57.0      45.0
# 9     The <a href="https://t.co/WLJYQmRqOK" rel="nof...    240.0     152.0
# 10    If you have the <a href="https://t.co/WLJYQmRq...    156.0     142.0
# 11    For those who claim that I recommend shitcoins...    921.0     578.0
# 12    The Coin Brothers (Buy the F-cking Dip) latest...    350.0     278.0
# 13    NIMBUS (<a href="https://t.co/6xV14Yat5I" rel=...    247.0     162.0
# 14    Since everyone wants to buy a coin at the coin...    114.0      34.0
# 15    A fascinating ICO - <a href="https://t.co/WLJY...    358.0     177.0
# 16    Fixed it, follow me:\n<a href="/SorryNoKYjelly...     24.0      24.0
# 17    A follower -  @SorryNoKYjelly has created a si...    248.0     173.0
# 18    Sunday family tweet. Marriage under normal cir...    619.0     179.0
# 19    Coin of the week: RIPIO Coin Network (RCN). RI...    506.0     464.0
# 20    I let my followers down. My team audits tons o...   1600.0     909.0
# 21    Yeah great to see <a href="/InsurePal_io" clas...     70.0      46.0
# 22    Yeah <a href="/InsurePal_io" class="twitter-at...     94.0      55.0
# 23    Incredible Satire Music Video - "Bitcoin Is A ...    322.0     203.0
# 24    Let's take a break from worrying about the mar...    473.0     308.0
# 25    Dome ask why I chose the  PODONE ICO  (<a href...    372.0     198.0
# 26    Again - "Buy the f-cking dip". It will rebound...    519.0     499.0
# 27    I was paid nothing by this man!! Neither befor...    509.0     456.0
# 28    <a href="/hashtag/CheapChampagne?src=hash" dat...    108.0      25.0
# 29    Request: those who perpetually yell "stop", "n...    774.0     193.0
# ...                                                 ...      ...       ...
# 1907  <a href="/search?q=%24BTC&amp;src=ctag" data-q...      NaN       NaN
# 1908  <a href="/search?q=%24SC&amp;src=ctag" data-qu...      6.0       7.0
# 1909  When we break 700 and then 750, it's go time <...      2.0       1.0
# 1910  <a href="/search?q=%24SC&amp;src=ctag" data-qu...      3.0      21.0
# 1911  <a href="/search?q=%24DGB&amp;src=ctag" data-q...      1.0       3.0
# 1912  Bitcoin has died 56201 times already<a href="h...      NaN       NaN
# 1913  <img class="Emoji Emoji--forText" src="https:/...      3.0       1.0
# 1914  Watching <a href="/search?q=%24XRP&amp;src=cta...      NaN       3.0
# 1915  Expecting <a href="/search?q=%24ETH&amp;src=ct...      NaN       7.0
# 1916  Market cycle of <a href="/search?q=%24XRP&amp;...      NaN       2.0
# 1917  + this marketcap dominance graph looks perfect...      NaN       NaN
# 1918  <a href="/search?q=%24ETH&amp;src=ctag" data-q...      1.0       7.0
# 1919  <a href="/search?q=%24XRP&amp;src=ctag" data-q...      3.0       8.0
# 1920  <a href="/search?q=%24XRP&amp;src=ctag" data-q...      6.0      17.0
# 1921  <a href="/search?q=%24ETC&amp;src=ctag" data-q...      NaN       2.0
# 1922  <a href="/search?q=%24ETC&amp;src=ctag" data-q...      1.0       1.0
# 1923  <a href="/search?q=%24ETC&amp;src=ctag" data-q...      1.0       2.0
# 1924  <a href="/search?q=%24XRP&amp;src=ctag" data-q...      3.0      15.0
# 1925                                   BTC to $2000 on:      NaN       NaN
# 1926  A coin goes up forever, until you buy it. <a h...      NaN       NaN
# 1927  Did you enjoy the ride? Now it's time for cons...      2.0       NaN
# 1928  Checking <a href="/search?q=%24BTC&amp;src=cta...      NaN       3.0
# 1929  Everyone looking at altcoins but they all depe...      1.0       1.0
# 1930  Poloniex down, Bitcoin mooning. Stay relaxed \...      1.0       2.0
# 1931  Altcoins vs Bitcoin<a href="https://t.co/MpgX4...      8.0      49.0
# 1932  <a href="/search?q=%24SYS&amp;src=ctag" data-q...      NaN       1.0
# 1933  Checking <a href="/search?q=%24XRP&amp;src=cta...      NaN       3.0
# 1934  <a href="/search?q=%24XRP&amp;src=ctag" data-q...      2.0       2.0
# 1935  If you missed yesterday's <a href="/search?q=%...      NaN       NaN
# 1936  <a href="/search?q=%24XRP&amp;src=ctag" data-q...      4.0       1.0
#
#          favs            user            timeStamp  \
# 0       807.0  officialmcafee  2018-02-02 13:19:00
# 1       215.0  officialmcafee  2018-02-02 10:37:00
# 2      1300.0  officialmcafee  2018-02-02 06:32:00
# 3      1300.0  officialmcafee  2018-02-02 04:19:00
# 4      6000.0  officialmcafee  2018-02-02 04:12:00
# 5       960.0  officialmcafee  2018-02-01 16:23:00
# 6     15000.0  officialmcafee  2018-02-01 10:54:00
# 7       588.0  officialmcafee  2018-02-01 10:08:00
# 8       169.0  officialmcafee  2018-01-30 13:04:00
# 9       474.0  officialmcafee  2018-01-31 08:19:00
# 10      483.0  officialmcafee  2018-01-31 07:23:00
# 11     2900.0  officialmcafee  2018-01-31 06:39:00
# 12     1100.0  officialmcafee  2018-01-30 21:57:00
# 13      782.0  officialmcafee  2018-01-30 13:59:00
# 14      214.0  officialmcafee  2018-01-29 17:01:00
# 15      732.0  officialmcafee  2018-01-29 11:52:00
# 16       81.0  officialmcafee  2018-01-29 03:12:00
# 17      787.0  officialmcafee  2018-01-29 03:09:00
# 18     3100.0  officialmcafee  2018-01-28 12:45:00
# 19     1500.0  officialmcafee  2018-01-28 11:35:00
# 20     4200.0  officialmcafee  2018-01-28 02:39:00
# 21      168.0  officialmcafee  2018-01-26 14:14:00
# 22      180.0  officialmcafee  2018-01-25 04:36:00
# 23      863.0  officialmcafee  2018-01-24 22:08:00
# 24     1600.0  officialmcafee  2018-01-24 18:06:00
# 25      763.0  officialmcafee  2018-01-24 10:07:00
# 26     1900.0  officialmcafee  2018-01-23 20:34:00
# 27     3100.0  officialmcafee  2018-01-23 02:18:00
# 28      437.0  officialmcafee  2018-01-23 01:41:00
# 29     3700.0  officialmcafee  2018-01-22 17:33:00
# ...       ...             ...                  ...
# 1907      NaN   cryptousemaki  2017-06-05 14:52:00
# 1908     12.0   cryptousemaki  2017-06-05 14:19:00
# 1909      3.0   cryptousemaki  2017-06-05 11:47:00
# 1910     45.0   cryptousemaki  2017-06-05 10:18:00
# 1911      6.0   cryptousemaki  2017-06-03 03:03:00
# 1912      4.0   cryptousemaki  2017-06-02 06:47:00
# 1913      3.0   cryptousemaki  2017-06-01 18:01:00
# 1914      7.0   cryptousemaki  2017-06-01 14:18:00
# 1915      7.0   cryptousemaki  2017-06-01 13:12:00
# 1916      1.0   cryptousemaki  2017-05-30 15:23:00
# 1917      1.0   cryptousemaki  2017-05-30 15:09:00
# 1918      8.0   cryptousemaki  2017-05-30 15:07:00
# 1919     16.0   cryptousemaki  2017-05-25 23:31:00
# 1920     43.0   cryptousemaki  2017-05-25 12:42:00
# 1921      7.0   cryptousemaki  2017-05-24 05:27:00
# 1922      6.0   cryptousemaki  2017-05-24 05:16:00
# 1923      8.0   cryptousemaki  2017-05-23 13:06:00
# 1924     37.0   cryptousemaki  2017-05-23 12:18:00
# 1925      NaN   cryptousemaki  2017-05-20 01:10:00
# 1926      5.0   cryptousemaki  2017-05-16 13:33:00
# 1927      2.0   cryptousemaki  2017-05-12 04:51:00
# 1928      2.0   cryptousemaki  2017-05-10 23:20:00
# 1929      5.0   cryptousemaki  2017-05-09 06:49:00
# 1930      3.0   cryptousemaki  2017-05-08 20:36:00
# 1931    109.0   cryptousemaki  2017-05-08 14:11:00
# 1932      NaN   cryptousemaki  2017-05-08 05:53:00
# 1933      3.0   cryptousemaki  2017-05-07 04:22:00
# 1934      4.0   cryptousemaki  2017-05-07 01:21:00
# 1935      2.0   cryptousemaki  2017-05-06 15:08:00
# 1936      4.0   cryptousemaki  2017-05-05 16:54:00
#
#                                              new_tweets       new_dts  \
# 0     alpha ii video w in this video you see just ho...  1.517549e+09
# 1                                        price increase  1.517539e+09
# 2     looking for a woman with ex sof military exper...  1.517524e+09
# 3                 coin brothers buy the fucking dip via  1.517516e+09
# 4     lot's of people asking me over the past two da...  1.517516e+09
# 5     call for white papers there are more than new ...  1.517473e+09
# 6     we are in a revolution against the waning powe...  1.517454e+09
# 7     freelancers are of the workforce removes middl...  1.517451e+09
# 8     john mcafee group buy tshirt eu amp usa free s...  1.517289e+09
# 9     the ico is performing well the token price is ...  1.517358e+09
# 10    if you have the app whether or not you investe...  1.517355e+09
# 11    for those who claim that i recommend shitcoins...  1.517352e+09
# 12    the coin brothers buy the fcking dip latest vi...  1.517321e+09
# 13    nimbus was an ico that we recommended two week...  1.517292e+09
# 14    since everyone wants to buy a coin at the coin...  1.517216e+09
# 15    a fascinating ico combines social media with p...  1.517198e+09
# 16    fixed it follow me has created a site listing ...  1.517167e+09
# 17    a follower sorrynokyjelly has created a site l...  1.517167e+09
# 18    sunday family tweet marriage under normal circ...  1.517115e+09
# 19    coin of the week ripio coin network rcn ripio ...  1.517110e+09
# 20    i let my followers down my team audits tons of...  1.517078e+09
# 21    yeah great to see project token on and exchang...  1.516947e+09
# 22    yeah will be huge know that stock on now befor...  1.516826e+09
# 23    incredible satire music video bitcoin is a bubble  1.516803e+09
# 24    let's take a break from worrying about the mar...  1.516788e+09
# 25    dome ask why i chose the podone ico instead of...  1.516760e+09
# 26    again buy the fcking dip it will rebound the m...  1.516711e+09
# 27    i was paid nothing by this man neither before ...  1.516645e+09
# 28                                                 scup  1.516643e+09
# 29    request those who perpetually yell stop nobody...  1.516614e+09
# ...                                                 ...           ...
# 1907                    has passed nothing new carry on  1.496646e+09
# 1908                         doom mode best time to buy  1.496644e+09
# 1909                when we break and then it's go time  1.496634e+09
# 1910  preparing for takeoff this time for potential ...  1.496629e+09
# 1911   todaytomorrow target satsh chart stoch rsi stong  1.496430e+09
# 1912                     bitcoin has died times already  1.496357e+09
# 1913  soon™ marketcap will surpass marketcap once ag...  1.496311e+09
# 1914  watching chart and chilling fun to watch chart...  1.496298e+09
# 1915       expecting marketcap parity at b in daysweeks  1.496294e+09
# 1916                  market cycle of cripple ⇆ tripple  1.496129e+09
# 1917  this marketcap dominance graph looks perfectly...  1.496128e+09
# 1918  marketcap dominance has passed and still below...  1.496128e+09
# 1919  update first target ~ level when we break ath ...  1.495726e+09
# 1920  at sats on fibonacci is a buy get on the ship ...  1.495687e+09
# 1921                                    holders be like  1.495575e+09
# 1922  hit the target in day still strong af next target  1.495574e+09
# 1923  update heading to fibonacci level and it's str...  1.495516e+09
# 1924  breaking out it may go down a little bit befor...  1.495513e+09
# 1925                                          btc to on  1.495214e+09
# 1926            a coin goes up forever until you buy it  1.494913e+09
# 1927  did you enjoy the ride now it's time for conso...  1.494536e+09
# 1928                                checking price like  1.494430e+09
# 1929  everyone looking at altcoins but they all depe...  1.494284e+09
# 1930         poloniex down bitcoin mooning stay relaxed  1.494247e+09
# 1931                                altcoins vs bitcoin  1.494224e+09
# 1932  signals selloff rsi amp price doesn't correlat...  1.494194e+09
# 1933                  checking price after a while like  1.494102e+09
# 1934  here we go playing out well hope you got in be...  1.494091e+09
# 1935  if you missed yesterday's entry this may be la...  1.494054e+09
# 1936  th elliot consolidation wave stoch rsi decreas...  1.493974e+09
#
#      assigned_member  coinMentioned  termsMentioned  \
# 0              daryl          False            True
# 1              daryl          False            True
# 2              daryl           True            True
# 3              daryl          False            True
# 4              daryl           True            True
# 5              daryl          False            True
# 6              daryl           True            True
# 7              daryl           True            True
# 8              daryl           True            True
# 9              daryl          False            True
# 10             daryl           True           False
# 11             daryl           True            True
# 12             daryl          False            True
# 13             daryl          False            True
# 14             daryl           True            True
# 15             daryl           True            True
# 16             daryl           True            True
# 17             daryl           True            True
# 18             daryl           True           False
# 19             daryl          False            True
# 20             daryl           True            True
# 21             daryl          False            True
# 22             daryl          False            True
# 23             daryl           True           False
# 24             daryl          False            True
# 25             daryl           True            True
# 26             daryl          False            True
# 27             daryl          False            True
# 28             daryl           True           False
# 29             daryl           True            True
# ...              ...            ...             ...
# 1907          daniel          False            True
# 1908          daniel          False            True
# 1909          daniel          False            True
# 1910          daniel           True            True
# 1911          daniel          False            True
# 1912          daniel           True           False
# 1913          daniel           True            True
# 1914          daniel          False            True
# 1915          daniel           True            True
# 1916          daniel           True            True
# 1917          daniel           True            True
# 1918          daniel           True            True
# 1919          daniel          False            True
# 1920          daniel          False            True
# 1921          daniel          False            True
# 1922          daniel           True           False
# 1923          daniel           True            True
# 1924          daniel          False            True
# 1925          daniel           True           False
# 1926          daniel          False            True
# 1927          daniel          False            True
# 1928          daniel          False            True
# 1929          daniel           True           False
# 1930          daniel           True           False
# 1931          daniel           True           False
# 1932          daniel           True            True
# 1933          daniel          False            True
# 1934          daniel          False            True
# 1935          daniel          False            True
# 1936          daniel           True            True
#
#                                         new_tweets_stem
# 0     alpha ii video w in this video you see just ho...
# 1                                         price increas
# 2     look for a woman with ex sof militari experi t...
# 3                     coin brother buy the fuck dip via
# 4     lot of peopl ask me over the past two day whet...
# 5     call for white paper there are more than new i...
# 6     we are in a revolut against the wane power of ...
# 7     freelanc are of the workforc remov middlemen f...
# 8      john mcafe group buy tshirt eu amp usa free ship
# 9     the ico is perform well the token price is go ...
# 10    if you have the app whether or not you invest ...
# 11    for those who claim that i recommend shitcoin ...
# 12    the coin brother buy the fcking dip latest vid...
# 13    nimbus was an ico that we recommend two week a...
# 14    sinc everyon want to buy a coin at the coin lo...
# 15    a fascin ico combin social media with physic a...
# 16    fix it follow me has creat a site list all of ...
# 17    a follow sorrynokyjelli has creat a site list ...
# 18    sunday famili tweet marriag under normal circu...
# 19    coin of the week ripio coin network rcn ripio ...
# 20    i let my follow down my team audit ton of ico ...
# 21    yeah great to see project token on and exchang...
# 22    yeah will be huge know that stock on now befor...
# 23          incred satir music video bitcoin is a bubbl
# 24    let take a break from worri about the market p...
# 25    dome ask whi i chose the podon ico instead of ...
# 26    again buy the fcking dip it will rebound the m...
# 27    i was paid noth by this man neither befor nor ...
# 28                                                 scup
# 29    request those who perpetu yell stop nobodi car...
# ...                                                 ...
# 1907                         has pass noth new carri on
# 1908                         doom mode best time to buy
# 1909                  when we break and then it go time
# 1910  prepar for takeoff this time for potenti targe...
# 1911   todaytomorrow target satsh chart stoch rsi stong
# 1912                       bitcoin has die time alreadi
# 1913  soon™ marketcap will surpass marketcap onc aga...
# 1914  watch chart and chill fun to watch chart while...
# 1915           expect marketcap pariti at b in daysweek
# 1916                     market cycl of crippl ⇆ trippl
# 1917  this marketcap domin graph look perfect symmet...
# 1918  marketcap domin has pass and still below marke...
# 1919  updat first target ~ level when we break ath n...
# 1920  at sat on fibonacci is a buy get on the ship a...
# 1921                                     holder be like
# 1922  hit the target in day still strong af next target
# 1923  updat head to fibonacci level and it strong on...
# 1924  break out it may go down a littl bit befor tak...
# 1925                                          btc to on
# 1926               a coin goe up forev until you buy it
# 1927  did you enjoy the ride now it time for consoli...
# 1928                                   check price like
# 1929  everyon look at altcoin but they all depend on...
# 1930              poloniex down bitcoin moon stay relax
# 1931                                 altcoin vs bitcoin
# 1932  signal selloff rsi amp price doesn't correl on...
# 1933                     check price after a while like
# 1934  here we go play out well hope you got in befor...
# 1935  if you miss yesterday entri this may be last c...
# 1936  th elliot consolid wave stoch rsi decreas pote...
#
# [1937 rows x 14 columns]

# %% [markdown]
# ## 4) Up-Sampling Tweets

# %% [markdown]
# For all the users, there is an imbalance in the tweet's signal types. Generally there are more "buy" signals as oppose to "sell" signals. Thus, we would want to upsample the "sell" signal which will help us perform 2 tasks. <br>
#
# <ol>1. Balance the signal types of tweets for each user</ol>
# <ol>2. Improve the learning ability of the models*</ol>
#
# *It was observed that in approach 1 and 2, some models would plainly classify tweets to the most common class if not worst than the plain classifier. This would show that the learner has not effectively "learned" to classify tweets between both classes. This would explain why we received "information gain" <= 0.

# %%
### Pre-Process
### X: Original Tweets as Series
### y: Original Target as Series

### Post-Process
### up_X: Up Sample Tweets as list
### up_y: Up Sample Targets as list

### Set the seed outside of this function so as not to always sample the way for each usage ###
### Up_samps for any different number of classes

def up_samp_data(X, y):
    class_val_counts = y.value_counts()
    classes = y.unique()
    
    max_class = classes[0]
    max_class_size = 1
    
    for c in classes:
        if class_val_counts[c] > max_class_size:
            max_class_size = class_val_counts[c]
            max_class = c
    
    up_X = list(X)
    up_y = list(y)
    
    for c in classes:
        if c != max_class:
            min_class_pos_in_y = [pos for pos in range(len(up_y)) if up_y[pos] == c]

            up_samp_pos = np.random.randint(len(min_class_pos_in_y), size = class_val_counts[max_class] - class_val_counts[c])

            for pos in up_samp_pos:
                up_X.append(up_X[min_class_pos_in_y[pos]])
                up_y.append(up_y[min_class_pos_in_y[pos]])

    return up_X, up_y

def shuffle_data(X, y):
    assert len(X) == len(y)
    shuffle_pos = np.arange(len(X))
    np.random.shuffle(shuffle_pos)
    return [X[pos] for pos in shuffle_pos], [y[pos] for pos in shuffle_pos]

# %%
### MAIN
all_users = all_tweets.user.unique()
print(all_users)
### Iterate for all user's tweets with the exception for user 1 because he does not have a sell signal
RES_FOLDER_PATH = "twt user results (3 class + stemmed + upsamp) app6"

### MODELS DICTIONARY
lr = LogisticRegression(solver="lbfgs")
svc = LinearSVC()
nb = MultinomialNB()
dt = DecisionTreeClassifier()

model_dict = {
    'LogReg': lr,
    'LinSVC': svc,
    'MultiNB': nb
}

### SAVE RESULTS
for user_pos in range(1, len(all_tweets.user.unique())):
    
    np.random.seed(4222)
    
    user = all_tweets.user.unique()[user_pos]
    print(user)
    user_df = all_tweets[(all_tweets.user == user)]
    
    X, y = up_samp_data(user_df.new_tweets_stem, user_df['Buy/Neutral/Sell'])
    X, y = shuffle_data(X, y)
    
    for model_name in model_dict.keys():
        print(model_name)
        vect = CountVectorizer(stop_words=new_stop_words)
        model = model_dict[model_name]
        n_runs = 100
        split_size = 5
        print_itr = False

        index, full_sell_words, full_neut_words, full_buy_words, full_train_accs, full_test_accs, full_test_null_accs, full_train_null_accs, full_test_conf_mats, full_train_conf_mats = ml_cv(X, y, vect, model, n_runs, split_size, print_itr)
        
        df_full_buy_words = pd.DataFrame(full_buy_words, index = index)
        df_full_buy_words.to_csv("./{RES_FOLDER_PATH}/{user}/{model_name}_full_buy_words.csv".format(RES_FOLDER_PATH = RES_FOLDER_PATH,user = user, model_name = model_name))
        
        df_full_neut_words = pd.DataFrame(full_neut_words, index = index)
        df_full_neut_words.to_csv("./{RES_FOLDER_PATH}/{user}/{model_name}_full_neut_words.csv".format(RES_FOLDER_PATH = RES_FOLDER_PATH,user = user, model_name = model_name))
        
        df_full_sell_words = pd.DataFrame(full_sell_words, index = index)
        df_full_sell_words.to_csv("./{RES_FOLDER_PATH}/{user}/{model_name}_full_sell_words.csv".format(RES_FOLDER_PATH = RES_FOLDER_PATH, user = user, model_name = model_name))
        
        #print(full_train_conf_mats[0])
        
        full_train_conf_mat_dict = {}
        for i in range(len(full_train_conf_mats[0])):
            for j in range(len(full_train_conf_mats[0][0])):
                true_i_pred_j = []
                for n_row in range(len(full_train_conf_mats)):
                    ind = "train_true_c{i}_pred_c{j}".format(i = i, j = j)
                    true_i_pred_j.append(full_train_conf_mats[n_row][i][j])
                full_train_conf_mat_dict[ind] = true_i_pred_j
        
        full_test_conf_mat_dict = {}
        for i in range(len(full_test_conf_mats[0])):
            for j in range(len(full_test_conf_mats[0][0])):
                true_i_pred_j = []
                for n_row in range(len(full_test_conf_mats)):
                    ind = "test_true_c{i}_pred_c{j}".format(i = i, j = j)
                    true_i_pred_j.append(full_test_conf_mats[n_row][i][j])
                full_test_conf_mat_dict[ind] = true_i_pred_j
        
        df_full_train_conf_mat = pd.DataFrame(full_train_conf_mat_dict, index = index)
        df_full_test_conf_mat = pd.DataFrame(full_test_conf_mat_dict, index = index)
        
        df_full_accs = pd.DataFrame({'full_train_accs': full_train_accs,
                                       'full_train_null_accs': full_train_null_accs,
                                       'full_test_accs': full_test_accs, 
                                       'full_test_null_accs': full_test_null_accs}, index = index)
        
        df_full_scores = pd.concat([df_full_accs, df_full_test_conf_mat, df_full_train_conf_mat], axis = 1)                                  

        df_full_scores.to_csv("./{RES_FOLDER_PATH}/{user}/{model_name}_full_scores.csv".format(RES_FOLDER_PATH = RES_FOLDER_PATH, user = user, model_name = model_name))
# Out:
# ['officialmcafee' 'CryptoYoda1338' 'ZeusZissou' 'anbessa100'
#  'cryptousemaki']
# CryptoYoda1338
# LogReg
# LinSVC
# MultiNB
# ZeusZissou
# LogReg
# LinSVC
# MultiNB
# anbessa100
# LogReg
# LinSVC
# MultiNB
# cryptousemaki
# LogReg
# LinSVC
# MultiNB

# %%
user = all_tweets.user.unique()[1]
print(user)
user_df = all_tweets[(all_tweets.user == user)]
    
X, y = up_samp_data(user_df.new_tweets_stem, user_df['Buy/Neutral/Sell'])
X, y = shuffle_data(X, y)
vect = CountVectorizer(stop_words=new_stop_words)
model = LogisticRegression(multi_class='ovr', solver="lbfgs", fit_intercept=False)

X_dtm = vect.fit_transform(X)

model.fit(X_dtm, y)

df1 = pd.DataFrame({'coef': model.coef_[2], 'words': vect.get_feature_names()})
#print(df1.sort_values('coef', ascending=False)[1:10])
df2 = pd.DataFrame({'coef': model.coef_[0], 'words': vect.get_feature_names()})
#print(df2.sort_values('coef', ascending=True)[1:10])

def log_reg(x):
    return 1/(1+np.e**(-x))

#print(X_dtm[0].toarray()[0])

a = log_reg(np.dot(X_dtm[0].toarray()[0], model.coef_[0]) + model.intercept_[0])
b = log_reg(np.dot(X_dtm[0].toarray()[0], model.coef_[1]) + model.intercept_[1])
c = log_reg(np.dot(X_dtm[0].toarray()[0], model.coef_[2]) + model.intercept_[2])
res = [a, b, c]
res = res/sum(res)
#print(res)
#print(model.intercept_)
#print(model.predict_proba(X_dtm)[0])

max_pos = [np.argmax(a) for a in model.coef_.transpose()]
classes = [-1, 0, 1]
np.unique(max_pos)

top_words_dicts = []
for c in classes:
    top_words_dicts.append({'coef': [], 'word': []})
    
for coef_ls, word in zip(model.coef_.transpose(), vect.get_feature_names()):
    top_words_dicts[np.argmax(coef_ls)]['coef'].append(np.max(coef_ls))
    top_words_dicts[np.argmax(coef_ls)]['word'].append(word)

temp_df = pd.DataFrame(top_words_dicts[0])
print(temp_df.sort_values('coef', ascending=False)[:10])
temp_df = pd.DataFrame(top_words_dicts[1])
print(temp_df.sort_values('coef', ascending=False)[:10])
temp_df = pd.DataFrame(top_words_dicts[2])
print(temp_df.sort_values('coef', ascending=False)[:10])
# Out:
# CryptoYoda1338
#          coef      word
# 75   1.717943     lower
# 22   1.382459     crash
# 65   1.334767   instead
# 73   1.285281       leg
# 138  1.261662      view
# 34   1.178995      drop
# 83   1.135388      mind
# 84   1.120154    mistak
# 97   1.111151   preceed
# 115  1.111151  similiar
#          coef      word
# 193  1.410608    crypto
# 112  1.237933      btce
# 591  1.237472    observ
# 351  1.210126     futur
# 443  1.190740  interest
# 129  0.974482      case
# 654  0.961350     posit
# 931  0.899102        ur
# 89   0.888869   bitcoin
# 957  0.880930      wedg
#          coef     word
# 182  1.393049     look
# 77   1.200143  develop
# 312  1.163123  trigger
# 279  1.086150     soon
# 235  1.027951  probabl
# 79   1.002916    doubl
# 323  0.986646  uptrend
# 322  0.981726    upsid
# 177  0.978907    level
# 51   0.953491    chase

# %%
user = all_tweets.user.unique()[1]
print(user)
user_df = all_tweets[(all_tweets.user == user)]
    
X, y = up_samp_data(user_df.new_tweets_stem, user_df['Buy/Neutral/Sell'])
X, y = shuffle_data(X, y)
vect = CountVectorizer(stop_words=new_stop_words)
model = DecisionTreeClassifier()

X_dtm = vect.fit_transform(X)

model.fit(X_dtm, y)

model.feature_importances_
model.decision_path(X_dtm)

export_graphviz(model)
# Out:
# CryptoYoda1338
# C:\Users\Daniel Chia\Anaconda3\lib\site-packages\sklearn\tree\export.py:399: DeprecationWarning: out_file can be set to None starting from 0.18. This will be the default in 0.20.
#   DeprecationWarning)

# %% [markdown]
# ## 4) Visualization

# %% [markdown]
# We look at the performance of the 3 models by evaluating the box plots of the accuracy scores from the test sets and the Area Under Curve scores from the test sets.

# %%
# READ ALL THE DATA
model_names = ['LogReg', 'LinSVC', 'MultiNB']

res_dict = {}

RES_FOLDER_PATH = "twt user results (3 class + stemmed + upsamp) app6"

# Get all the scoring results
for model_name in model_names:
    mod_dict = {}
    for user in all_users[1:len(all_users)]:
        path = "./{RES_FOLDER_PATH}/{user}/{model_name}_full_scores.csv".format(RES_FOLDER_PATH = RES_FOLDER_PATH,user = user, model_name = model_name)
        res = pd.read_csv(path, index_col=0)
        mod_dict[user] = res
    res_dict[model_name] = mod_dict

# %%
# Types of Scores from the data
res_types = res_dict[model_name][user].columns
res_types
# Out:
# Index(['full_test_accs', 'full_test_null_accs', 'full_train_accs',
#        'full_train_null_accs', 'test_true_c0_pred_c0', 'test_true_c0_pred_c1',
#        'test_true_c0_pred_c2', 'test_true_c1_pred_c0', 'test_true_c1_pred_c1',
#        'test_true_c1_pred_c2', 'test_true_c2_pred_c0', 'test_true_c2_pred_c1',
#        'test_true_c2_pred_c2', 'train_true_c0_pred_c0',
#        'train_true_c0_pred_c1', 'train_true_c0_pred_c2',
#        'train_true_c1_pred_c0', 'train_true_c1_pred_c1',
#        'train_true_c1_pred_c2', 'train_true_c2_pred_c0',
#        'train_true_c2_pred_c1', 'train_true_c2_pred_c2'],
#       dtype='object')

# %%
### helper function to extract all of the possible info
def get_model_all_user_scores(mod_dict, res_type):
    all_user_scores_dict = {}
    for user in mod_dict.keys():
        all_user_scores_dict[user] = mod_dict[user][res_type]
    
    df_all_user_scores = pd.DataFrame(all_user_scores_dict)
    
    return df_all_user_scores

### Combine scores of all users and models
def get_all_scores(res_dict, res_type):
    df_res = pd.DataFrame()
    for model in res_dict.keys():
        df_model = get_model_all_user_scores(res_dict[model], res_type)
        df_model = df_model.reset_index()
        df_model['model'] = pd.Series([model] * len(df_model))
        df_res = df_res.append(df_model)
    df_res = df_res.reset_index()
    df_res = df_res.drop('level_0', axis = 1)
    return df_res

# %%
### transform conf mat in ovr format
### return to binary classification, expecting 3 forms of conf mat
def make_ovr_conf_mat(conf_mat):
    num_class = conf_mat.shape[0]
    res_ovr_conf_mat = []
    for c in range(num_class):
        t_curr_p_curr, t_curr_p_oppo, t_oppo_p_curr, t_oppo_p_oppo = 0, 0, 0, 0
        t_curr_p_curr = conf_mat[c][c]
        for oppo in range(num_class):
            if oppo != c:
                t_curr_p_oppo = t_curr_p_oppo + conf_mat[c][oppo]
                t_oppo_p_curr = t_oppo_p_curr + conf_mat[oppo][c]
                for next_oppo in range(num_class):
                    if next_oppo != c:
                        t_oppo_p_oppo = t_oppo_p_oppo + conf_mat[oppo][next_oppo]
        res_ovr_conf_mat.append([[t_curr_p_curr, t_curr_p_oppo],[t_oppo_p_curr, t_oppo_p_oppo]])
    return res_ovr_conf_mat


### conf mat
for model in res_dict.keys():
    for user in res_dict[model].keys():
        for c0c0, c0c1, c0c2, c1c0, c1c1, c1c2, c2c0, c2c1, c2c2 in zip(res_dict[model][user]['test_true_c0_pred_c0'],
            res_dict[model][user]['test_true_c0_pred_c1'],
            res_dict[model][user]['test_true_c0_pred_c2'],
            res_dict[model][user]['test_true_c1_pred_c0'],
            res_dict[model][user]['test_true_c1_pred_c1'],
            res_dict[model][user]['test_true_c1_pred_c2'],
            res_dict[model][user]['test_true_c2_pred_c0'],
            res_dict[model][user]['test_true_c2_pred_c1'],
            res_dict[model][user]['test_true_c2_pred_c2']
        ):
        
            curr_conf_mat = np.array([c0c0, c0c1, c0c2, c1c0, c1c1, c1c2, c2c0, c2c1, c2c2]).reshape(3, 3)
            print(make_ovr_conf_mat(curr_conf_mat))
# Out:
# [[[58, 0], [2, 114]], [[44, 14], [6, 110]], [[51, 7], [13, 103]]]
# [[[58, 0], [0, 116]], [[52, 6], [15, 101]], [[43, 15], [6, 110]]]
# [[[57, 0], [3, 111]], [[38, 19], [7, 107]], [[50, 7], [16, 98]]]
# [[[57, 0], [2, 112]], [[39, 18], [9, 105]], [[47, 10], [17, 97]]]
# [[[57, 0], [0, 114]], [[43, 14], [8, 106]], [[49, 8], [14, 100]]]
# [[[58, 0], [0, 116]], [[45, 13], [6, 110]], [[52, 6], [13, 103]]]
# [[[58, 0], [1, 115]], [[48, 10], [10, 106]], [[48, 10], [9, 107]]]
# [[[57, 0], [0, 114]], [[43, 14], [2, 112]], [[55, 2], [14, 100]]]
# [[[57, 0], [4, 110]], [[42, 15], [14, 100]], [[41, 16], [13, 101]]]
# [[[57, 0], [3, 111]], [[35, 22], [13, 101]], [[43, 14], [20, 94]]]
# [[[58, 0], [0, 116]], [[40, 18], [12, 104]], [[46, 12], [18, 98]]]
# [[[58, 0], [5, 111]], [[40, 18], [14, 102]], [[44, 14], [13, 103]]]
# [[[57, 0], [2, 112]], [[44, 13], [2, 112]], [[55, 2], [11, 103]]]
# [[[57, 0], [1, 113]], [[49, 8], [6, 108]], [[50, 7], [8, 106]]]
# [[[57, 0], [1, 113]], [[44, 13], [12, 102]], [[44, 13], [13, 101]]]
# [[[58, 0], [0, 116]], [[42, 16], [8, 108]], [[50, 8], [16, 100]]]
# [[[58, 0], [1, 115]], [[44, 14], [13, 103]], [[44, 14], [14, 102]]]
# [[[57, 0], [3, 111]], [[34, 23], [9, 105]], [[46, 11], [22, 92]]]
# [[[57, 0], [2, 112]], [[45, 12], [10, 104]], [[47, 10], [10, 104]]]
# [[[57, 0], [3, 111]], [[47, 10], [13, 101]], [[43, 14], [8, 106]]]
# [[[58, 0], [2, 114]], [[44, 14], [7, 109]], [[50, 8], [13, 103]]]
# [[[58, 0], [6, 110]], [[38, 20], [13, 103]], [[43, 15], [16, 100]]]
# [[[57, 0], [1, 113]], [[43, 14], [9, 105]], [[48, 9], [13, 101]]]
# [[[57, 0], [1, 113]], [[46, 11], [9, 105]], [[48, 9], [10, 104]]]
# [[[57, 0], [0, 114]], [[38, 19], [7, 107]], [[50, 7], [19, 95]]]
# [[[58, 0], [1, 115]], [[37, 21], [8, 108]], [[50, 8], [20, 96]]]
# [[[58, 0], [3, 113]], [[44, 14], [13, 103]], [[44, 14], [12, 104]]]
# [[[57, 0], [2, 112]], [[42, 15], [14, 100]], [[43, 14], [13, 101]]]
# [[[57, 0], [3, 111]], [[50, 7], [8, 106]], [[47, 10], [6, 108]]]
# [[[57, 0], [0, 114]], [[41, 16], [6, 108]], [[51, 6], [16, 98]]]
# [[[58, 0], [3, 113]], [[44, 14], [6, 110]], [[51, 7], [12, 104]]]
# [[[58, 0], [2, 114]], [[47, 11], [9, 107]], [[49, 9], [9, 107]]]
# [[[57, 0], [4, 110]], [[37, 20], [7, 107]], [[48, 9], [18, 96]]]
# [[[57, 0], [0, 114]], [[45, 12], [10, 104]], [[47, 10], [12, 102]]]
# [[[57, 0], [2, 112]], [[42, 15], [14, 100]], [[42, 15], [14, 100]]]
# [[[58, 0], [2, 114]], [[41, 17], [10, 106]], [[47, 11], [16, 100]]]
# [[[58, 0], [3, 113]], [[37, 21], [6, 110]], [[52, 6], [18, 98]]]
# [[[57, 0], [2, 112]], [[43, 14], [7, 107]], [[49, 8], [13, 101]]]
# [[[57, 0], [0, 114]], [[43, 14], [10, 104]], [[47, 10], [14, 100]]]
# [[[57, 0], [0, 114]], [[46, 11], [13, 101]], [[44, 13], [11, 103]]]
# [[[58, 0], [1, 115]], [[41, 17], [9, 107]], [[49, 9], [16, 100]]]
# [[[58, 0], [3, 113]], [[42, 16], [9, 107]], [[49, 9], [13, 103]]]
# [[[57, 0], [1, 113]], [[47, 10], [13, 101]], [[44, 13], [9, 105]]]
# [[[57, 0], [2, 112]], [[37, 20], [14, 100]], [[43, 14], [18, 96]]]
# [[[57, 0], [3, 111]], [[43, 14], [8, 106]], [[46, 11], [14, 100]]]
# [[[58, 0], [2, 114]], [[45, 13], [11, 105]], [[47, 11], [11, 105]]]
# [[[58, 0], [3, 113]], [[48, 10], [8, 108]], [[48, 10], [9, 107]]]
# [[[57, 0], [2, 112]], [[43, 14], [8, 106]], [[49, 8], [12, 102]]]
# [[[57, 0], [0, 114]], [[40, 17], [6, 108]], [[51, 6], [17, 97]]]
# [[[57, 0], [3, 111]], [[43, 14], [11, 103]], [[44, 13], [13, 101]]]
# [[[58, 0], [3, 113]], [[44, 14], [10, 106]], [[47, 11], [12, 104]]]
# [[[58, 0], [2, 114]], [[42, 16], [8, 108]], [[49, 9], [15, 101]]]
# [[[57, 0], [2, 112]], [[43, 14], [7, 107]], [[49, 8], [13, 101]]]
# [[[57, 0], [1, 113]], [[43, 14], [10, 104]], [[47, 10], [13, 101]]]
# [[[57, 0], [2, 112]], [[39, 18], [11, 103]], [[45, 12], [17, 97]]]
# [[[58, 0], [0, 116]], [[46, 12], [7, 109]], [[51, 7], [12, 104]]]
# [[[58, 0], [9, 107]], [[36, 22], [5, 111]], [[46, 12], [20, 96]]]
# [[[57, 0], [1, 113]], [[40, 17], [8, 106]], [[49, 8], [16, 98]]]
# [[[57, 0], [1, 113]], [[41, 16], [9, 105]], [[48, 9], [15, 99]]]
# [[[57, 0], [1, 113]], [[51, 6], [12, 102]], [[44, 13], [6, 108]]]
# [[[58, 0], [1, 115]], [[38, 20], [7, 109]], [[50, 8], [20, 96]]]
# [[[58, 0], [0, 116]], [[48, 10], [5, 111]], [[53, 5], [10, 106]]]
# [[[57, 0], [2, 112]], [[41, 16], [8, 106]], [[47, 10], [16, 98]]]
# [[[57, 0], [0, 114]], [[46, 11], [12, 102]], [[45, 12], [11, 103]]]
# [[[57, 0], [2, 112]], [[43, 14], [5, 109]], [[52, 5], [12, 102]]]
# [[[58, 0], [1, 115]], [[48, 10], [10, 106]], [[47, 11], [10, 106]]]
# [[[58, 0], [1, 115]], [[43, 15], [9, 107]], [[48, 10], [15, 101]]]
# [[[57, 0], [4, 110]], [[43, 14], [13, 101]], [[42, 15], [12, 102]]]
# [[[57, 0], [1, 113]], [[40, 17], [6, 108]], [[51, 6], [16, 98]]]
# [[[57, 0], [0, 114]], [[45, 12], [8, 106]], [[49, 8], [12, 102]]]
# [[[58, 0], [5, 111]], [[46, 12], [5, 111]], [[48, 10], [12, 104]]]
# [[[58, 0], [2, 114]], [[43, 15], [15, 101]], [[42, 16], [14, 102]]]
# [[[57, 0], [2, 112]], [[41, 16], [8, 106]], [[49, 8], [14, 100]]]
# [[[57, 0], [2, 112]], [[44, 13], [10, 104]], [[47, 10], [11, 103]]]
# [[[57, 0], [0, 114]], [[42, 15], [9, 105]], [[48, 9], [15, 99]]]
# [[[58, 0], [4, 112]], [[41, 17], [9, 107]], [[46, 12], [16, 100]]]
# [[[58, 0], [4, 112]], [[44, 14], [11, 105]], [[45, 13], [12, 104]]]
# [[[57, 0], [0, 114]], [[47, 10], [5, 109]], [[52, 5], [10, 104]]]
# [[[57, 0], [0, 114]], [[49, 8], [10, 104]], [[47, 10], [8, 106]]]
# [[[57, 0], [2, 112]], [[41, 16], [12, 102]], [[45, 12], [14, 100]]]
# [[[58, 0], [2, 114]], [[40, 18], [7, 109]], [[50, 8], [17, 99]]]
# [[[58, 0], [2, 114]], [[49, 9], [11, 105]], [[45, 13], [9, 107]]]
# [[[57, 0], [4, 110]], [[40, 17], [10, 104]], [[46, 11], [14, 100]]]
# [[[57, 0], [1, 113]], [[51, 6], [16, 98]], [[41, 16], [5, 109]]]
# [[[57, 0], [0, 114]], [[47, 10], [11, 103]], [[46, 11], [10, 104]]]
# [[[58, 0], [1, 115]], [[43, 15], [8, 108]], [[50, 8], [14, 102]]]
# [[[58, 0], [2, 114]], [[46, 12], [10, 106]], [[46, 12], [12, 104]]]
# [[[57, 0], [1, 113]], [[44, 13], [8, 106]], [[49, 8], [12, 102]]]
# [[[57, 0], [1, 113]], [[41, 16], [12, 102]], [[45, 12], [15, 99]]]
# [[[57, 0], [4, 110]], [[39, 18], [8, 106]], [[48, 9], [15, 99]]]
# [[[58, 0], [1, 115]], [[43, 15], [8, 108]], [[50, 8], [14, 102]]]
# [[[58, 0], [1, 115]], [[44, 14], [13, 103]], [[45, 13], [13, 103]]]
# [[[57, 0], [1, 113]], [[39, 18], [10, 104]], [[46, 11], [18, 96]]]
# [[[57, 0], [2, 112]], [[41, 16], [9, 105]], [[48, 9], [14, 100]]]
# [[[57, 0], [1, 113]], [[49, 8], [11, 103]], [[45, 12], [8, 106]]]
# [[[58, 0], [2, 114]], [[46, 12], [12, 104]], [[46, 12], [10, 106]]]
# [[[58, 0], [1, 115]], [[38, 20], [4, 112]], [[54, 4], [19, 97]]]
# [[[57, 0], [1, 113]], [[41, 16], [8, 106]], [[48, 9], [16, 98]]]
# [[[57, 0], [2, 112]], [[45, 12], [9, 105]], [[46, 11], [12, 102]]]
# [[[57, 0], [2, 112]], [[42, 15], [10, 104]], [[47, 10], [13, 101]]]
# [[[58, 0], [3, 113]], [[43, 15], [8, 108]], [[48, 10], [14, 102]]]
# [[[58, 0], [0, 116]], [[40, 18], [8, 108]], [[50, 8], [18, 98]]]
# [[[57, 0], [3, 111]], [[40, 17], [11, 103]], [[45, 12], [15, 99]]]
# [[[57, 0], [3, 111]], [[41, 16], [7, 107]], [[49, 8], [14, 100]]]
# [[[57, 0], [2, 112]], [[46, 11], [8, 106]], [[49, 8], [9, 105]]]
# [[[58, 0], [3, 113]], [[40, 18], [8, 108]], [[49, 9], [16, 100]]]
# [[[58, 0], [1, 115]], [[43, 15], [13, 103]], [[45, 13], [14, 102]]]
# [[[57, 0], [2, 112]], [[41, 16], [10, 104]], [[46, 11], [15, 99]]]
# [[[57, 0], [3, 111]], [[41, 16], [7, 107]], [[49, 8], [14, 100]]]
# [[[57, 0], [3, 111]], [[47, 10], [7, 107]], [[49, 8], [8, 106]]]
# [[[58, 0], [0, 116]], [[42, 16], [10, 106]], [[48, 10], [16, 100]]]
# [[[58, 0], [3, 113]], [[48, 10], [12, 104]], [[45, 13], [8, 108]]]
# [[[57, 0], [4, 110]], [[46, 11], [14, 100]], [[41, 16], [9, 105]]]
# [[[57, 0], [2, 112]], [[45, 12], [6, 108]], [[50, 7], [11, 103]]]
# [[[57, 0], [0, 114]], [[35, 22], [11, 103]], [[46, 11], [22, 92]]]
# [[[58, 0], [3, 113]], [[42, 16], [13, 103]], [[42, 16], [16, 100]]]
# [[[58, 0], [0, 116]], [[41, 17], [10, 106]], [[48, 10], [17, 99]]]
# [[[57, 0], [3, 111]], [[42, 15], [10, 104]], [[47, 10], [12, 102]]]
# [[[57, 0], [5, 109]], [[44, 13], [10, 104]], [[44, 13], [11, 103]]]
# [[[57, 0], [0, 114]], [[47, 10], [9, 105]], [[48, 9], [10, 104]]]
# [[[58, 0], [2, 114]], [[40, 18], [13, 103]], [[45, 13], [16, 100]]]
# [[[58, 0], [1, 115]], [[45, 13], [6, 110]], [[51, 7], [13, 103]]]
# [[[57, 0], [1, 113]], [[42, 15], [15, 99]], [[42, 15], [14, 100]]]
# [[[57, 0], [0, 114]], [[42, 15], [11, 103]], [[46, 11], [15, 99]]]
# [[[57, 0], [1, 113]], [[46, 11], [9, 105]], [[47, 10], [11, 103]]]
# [[[58, 0], [0, 116]], [[42, 16], [12, 104]], [[46, 12], [16, 100]]]
# [[[58, 0], [0, 116]], [[50, 8], [8, 108]], [[50, 8], [8, 108]]]
# [[[57, 0], [5, 109]], [[37, 20], [10, 104]], [[45, 12], [17, 97]]]
# [[[57, 0], [2, 112]], [[41, 16], [9, 105]], [[47, 10], [15, 99]]]
# [[[57, 0], [2, 112]], [[40, 17], [7, 107]], [[50, 7], [15, 99]]]
# [[[58, 0], [1, 115]], [[47, 11], [7, 109]], [[50, 8], [11, 105]]]
# [[[58, 0], [1, 115]], [[47, 11], [14, 102]], [[44, 14], [10, 106]]]
# [[[57, 0], [3, 111]], [[38, 19], [6, 108]], [[51, 6], [16, 98]]]
# [[[57, 0], [1, 113]], [[45, 12], [8, 106]], [[48, 9], [12, 102]]]
# [[[57, 0], [1, 113]], [[45, 12], [11, 103]], [[45, 12], [12, 102]]]
# [[[58, 0], [2, 114]], [[39, 19], [9, 107]], [[49, 9], [17, 99]]]
# [[[58, 0], [6, 110]], [[40, 18], [8, 108]], [[45, 13], [17, 99]]]
# [[[57, 0], [1, 113]], [[44, 13], [7, 107]], [[50, 7], [12, 102]]]
# [[[57, 0], [2, 112]], [[48, 9], [12, 102]], [[44, 13], [8, 106]]]
# [[[57, 0], [1, 113]], [[44, 13], [10, 104]], [[46, 11], [13, 101]]]
# [[[58, 0], [1, 115]], [[46, 12], [11, 105]], [[47, 11], [11, 105]]]
# [[[58, 0], [3, 113]], [[42, 16], [10, 106]], [[48, 10], [13, 103]]]
# [[[57, 0], [0, 114]], [[43, 14], [8, 106]], [[49, 8], [14, 100]]]
# [[[57, 0], [4, 110]], [[39, 18], [3, 111]], [[52, 5], [16, 98]]]
# [[[57, 0], [1, 113]], [[45, 12], [9, 105]], [[47, 10], [12, 102]]]
# [[[58, 0], [2, 114]], [[45, 13], [11, 105]], [[46, 12], [12, 104]]]
# [[[58, 0], [1, 115]], [[42, 16], [18, 98]], [[40, 18], [15, 101]]]
# [[[57, 0], [3, 111]], [[38, 19], [6, 108]], [[49, 8], [18, 96]]]
# [[[57, 0], [0, 114]], [[43, 14], [4, 110]], [[53, 4], [14, 100]]]
# [[[57, 0], [0, 114]], [[43, 14], [11, 103]], [[46, 11], [14, 100]]]
# [[[58, 0], [2, 114]], [[43, 15], [7, 109]], [[50, 8], [14, 102]]]
# [[[58, 0], [1, 115]], [[46, 12], [10, 106]], [[47, 11], [12, 104]]]
# [[[57, 0], [1, 113]], [[34, 23], [8, 106]], [[49, 8], [22, 92]]]
# [[[57, 0], [2, 112]], [[44, 13], [9, 105]], [[47, 10], [12, 102]]]
# [[[57, 0], [3, 111]], [[48, 9], [12, 102]], [[44, 13], [7, 107]]]
# [[[58, 0], [5, 111]], [[40, 18], [10, 106]], [[45, 13], [16, 100]]]
# [[[58, 0], [1, 115]], [[51, 7], [7, 109]], [[51, 7], [6, 110]]]
# [[[57, 0], [2, 112]], [[45, 12], [8, 106]], [[48, 9], [11, 103]]]
# [[[57, 0], [3, 111]], [[35, 22], [10, 104]], [[46, 11], [20, 94]]]
# [[[57, 0], [0, 114]], [[45, 12], [11, 103]], [[46, 11], [12, 102]]]
# [[[58, 0], [2, 114]], [[43, 15], [12, 104]], [[44, 14], [15, 101]]]
# [[[58, 0], [2, 114]], [[43, 15], [10, 106]], [[48, 10], [13, 103]]]
# [[[57, 0], [3, 111]], [[43, 14], [3, 111]], [[53, 4], [12, 102]]]
# [[[57, 0], [1, 113]], [[44, 13], [10, 104]], [[47, 10], [12, 102]]]
# [[[53, 4], [1, 113]], [[45, 12], [11, 103]], [[46, 11], [15, 99]]]
# [[[58, 0], [1, 115]], [[53, 5], [13, 103]], [[44, 14], [5, 111]]]
# [[[58, 0], [2, 114]], [[41, 17], [8, 108]], [[49, 9], [16, 100]]]
# [[[57, 0], [4, 110]], [[42, 15], [12, 102]], [[44, 13], [12, 102]]]
# [[[57, 0], [1, 113]], [[40, 17], [9, 105]], [[48, 9], [16, 98]]]
# [[[57, 0], [0, 114]], [[45, 12], [10, 104]], [[47, 10], [12, 102]]]
# [[[58, 0], [3, 113]], [[44, 14], [10, 106]], [[47, 11], [12, 104]]]
# [[[58, 0], [1, 115]], [[46, 12], [12, 104]], [[45, 13], [12, 104]]]
# [[[57, 0], [1, 113]], [[45, 12], [12, 102]], [[45, 12], [11, 103]]]
# [[[57, 0], [2, 112]], [[43, 14], [12, 102]], [[43, 14], [14, 100]]]
# [[[57, 0], [1, 113]], [[36, 21], [3, 111]], [[54, 3], [20, 94]]]
# [[[58, 0], [1, 115]], [[41, 17], [8, 108]], [[50, 8], [16, 100]]]
# [[[58, 0], [1, 115]], [[41, 17], [3, 113]], [[54, 4], [17, 99]]]
# [[[57, 0], [3, 111]], [[42, 15], [10, 104]], [[46, 11], [13, 101]]]
# [[[57, 0], [1, 113]], [[43, 14], [9, 105]], [[48, 9], [13, 101]]]
# [[[57, 0], [3, 111]], [[39, 18], [10, 104]], [[46, 11], [16, 98]]]
# [[[58, 0], [1, 115]], [[48, 10], [8, 108]], [[49, 9], [10, 106]]]
# [[[58, 0], [2, 114]], [[43, 15], [4, 112]], [[54, 4], [13, 103]]]
# [[[57, 0], [1, 113]], [[41, 16], [8, 106]], [[49, 8], [15, 99]]]
# [[[57, 0], [3, 111]], [[41, 16], [7, 107]], [[49, 8], [14, 100]]]
# [[[57, 0], [2, 112]], [[42, 15], [14, 100]], [[43, 14], [13, 101]]]
# [[[58, 0], [0, 116]], [[40, 18], [7, 109]], [[51, 7], [18, 98]]]
# [[[58, 0], [2, 114]], [[37, 21], [11, 105]], [[46, 12], [20, 96]]]
# [[[57, 0], [1, 113]], [[43, 14], [11, 103]], [[45, 12], [14, 100]]]
# [[[57, 0], [1, 113]], [[45, 12], [10, 104]], [[47, 10], [11, 103]]]
# [[[57, 0], [2, 112]], [[47, 10], [10, 104]], [[45, 12], [10, 104]]]
# [[[58, 0], [1, 115]], [[36, 22], [9, 107]], [[48, 10], [22, 94]]]
# [[[58, 0], [0, 116]], [[48, 10], [11, 105]], [[47, 11], [10, 106]]]
# [[[57, 0], [8, 106]], [[37, 20], [6, 108]], [[46, 11], [17, 97]]]
# [[[57, 0], [2, 112]], [[46, 11], [7, 107]], [[49, 8], [10, 104]]]
# [[[57, 0], [1, 113]], [[43, 14], [11, 103]], [[46, 11], [13, 101]]]
# [[[58, 0], [1, 115]], [[40, 18], [11, 105]], [[47, 11], [17, 99]]]
# [[[58, 0], [2, 114]], [[42, 16], [8, 108]], [[49, 9], [15, 101]]]
# [[[57, 0], [1, 113]], [[43, 14], [8, 106]], [[48, 9], [14, 100]]]
# [[[57, 0], [1, 113]], [[47, 10], [7, 107]], [[49, 8], [10, 104]]]
# [[[57, 0], [2, 112]], [[43, 14], [8, 106]], [[49, 8], [12, 102]]]
# [[[58, 0], [1, 115]], [[44, 14], [6, 110]], [[51, 7], [14, 102]]]
# [[[58, 0], [2, 114]], [[43, 15], [9, 107]], [[48, 10], [14, 102]]]
# [[[57, 0], [2, 112]], [[46, 11], [8, 106]], [[49, 8], [9, 105]]]
# [[[57, 0], [0, 114]], [[47, 10], [14, 100]], [[43, 14], [10, 104]]]
# [[[57, 0], [2, 112]], [[35, 22], [7, 107]], [[49, 8], [21, 93]]]
# [[[58, 0], [0, 116]], [[43, 15], [11, 105]], [[47, 11], [15, 101]]]
# [[[58, 0], [2, 114]], [[43, 15], [12, 104]], [[44, 14], [15, 101]]]
# [[[57, 0], [4, 110]], [[44, 13], [9, 105]], [[47, 10], [10, 104]]]
# [[[57, 0], [1, 113]], [[42, 15], [11, 103]], [[46, 11], [14, 100]]]
# [[[57, 0], [0, 114]], [[44, 13], [4, 110]], [[53, 4], [13, 101]]]
# [[[58, 0], [0, 116]], [[48, 10], [12, 104]], [[46, 12], [10, 106]]]
# [[[58, 0], [2, 114]], [[43, 15], [11, 105]], [[45, 13], [15, 101]]]
# [[[57, 0], [3, 111]], [[41, 16], [8, 106]], [[47, 10], [15, 99]]]
# [[[57, 0], [2, 112]], [[43, 14], [14, 100]], [[43, 14], [12, 102]]]
# [[[57, 0], [4, 110]], [[41, 16], [11, 103]], [[44, 13], [14, 100]]]
# [[[58, 0], [3, 113]], [[42, 16], [6, 110]], [[50, 8], [15, 101]]]
# [[[58, 0], [2, 114]], [[42, 16], [13, 103]], [[45, 13], [14, 102]]]
# [[[57, 0], [2, 112]], [[44, 13], [9, 105]], [[47, 10], [12, 102]]]
# [[[57, 0], [1, 113]], [[46, 11], [11, 103]], [[45, 12], [11, 103]]]
# [[[57, 0], [1, 113]], [[40, 17], [6, 108]], [[51, 6], [16, 98]]]
# [[[58, 0], [1, 115]], [[46, 12], [12, 104]], [[46, 12], [11, 105]]]
# [[[58, 0], [2, 114]], [[44, 14], [8, 108]], [[48, 10], [14, 102]]]
# [[[57, 0], [2, 112]], [[41, 16], [12, 102]], [[44, 13], [15, 99]]]
# [[[57, 0], [3, 111]], [[43, 14], [6, 108]], [[50, 7], [12, 102]]]
# [[[57, 0], [0, 114]], [[44, 13], [10, 104]], [[47, 10], [13, 101]]]
# [[[58, 0], [1, 115]], [[47, 11], [19, 97]], [[38, 20], [11, 105]]]
# [[[58, 0], [1, 115]], [[42, 16], [6, 110]], [[51, 7], [16, 100]]]
# [[[57, 0], [3, 111]], [[38, 19], [9, 105]], [[48, 9], [16, 98]]]
# [[[57, 0], [3, 111]], [[42, 15], [15, 99]], [[42, 15], [12, 102]]]
# [[[57, 0], [4, 110]], [[40, 17], [6, 108]], [[49, 8], [15, 99]]]
# [[[58, 0], [1, 115]], [[43, 15], [8, 108]], [[50, 8], [14, 102]]]
# [[[58, 0], [3, 113]], [[43, 15], [10, 106]], [[47, 11], [13, 103]]]
# [[[57, 0], [2, 112]], [[40, 17], [10, 104]], [[46, 11], [16, 98]]]
# [[[57, 0], [1, 113]], [[47, 10], [13, 101]], [[44, 13], [9, 105]]]
# [[[57, 0], [3, 111]], [[43, 14], [8, 106]], [[47, 10], [13, 101]]]
# [[[58, 0], [2, 114]], [[42, 16], [10, 106]], [[47, 11], [15, 101]]]
# [[[58, 0], [1, 115]], [[44, 14], [12, 104]], [[46, 12], [13, 103]]]
# [[[57, 0], [2, 112]], [[46, 11], [7, 107]], [[49, 8], [10, 104]]]
# [[[57, 0], [1, 113]], [[45, 12], [4, 110]], [[52, 5], [12, 102]]]
# [[[57, 0], [1, 113]], [[41, 16], [9, 105]], [[48, 9], [15, 99]]]
# [[[58, 0], [2, 114]], [[42, 16], [7, 109]], [[51, 7], [14, 102]]]
# [[[58, 0], [3, 113]], [[44, 14], [5, 111]], [[52, 6], [12, 104]]]
# [[[57, 0], [1, 113]], [[45, 12], [11, 103]], [[45, 12], [12, 102]]]
# [[[57, 0], [0, 114]], [[44, 13], [11, 103]], [[46, 11], [13, 101]]]
# [[[57, 0], [2, 112]], [[38, 19], [14, 100]], [[42, 15], [18, 96]]]
# [[[58, 0], [2, 114]], [[44, 14], [12, 104]], [[45, 13], [13, 103]]]
# [[[58, 0], [0, 116]], [[42, 16], [8, 108]], [[50, 8], [16, 100]]]
# [[[57, 0], [4, 110]], [[40, 17], [6, 108]], [[50, 7], [14, 100]]]
# [[[57, 0], [4, 110]], [[41, 16], [2, 112]], [[55, 2], [12, 102]]]
# [[[57, 0], [1, 113]], [[49, 8], [15, 99]], [[41, 16], [8, 106]]]
# [[[58, 0], [1, 115]], [[42, 16], [15, 101]], [[43, 15], [15, 101]]]
# [[[58, 0], [2, 114]], [[47, 11], [7, 109]], [[50, 8], [10, 106]]]
# [[[57, 0], [2, 112]], [[43, 14], [5, 109]], [[50, 7], [14, 100]]]
# [[[57, 0], [1, 113]], [[46, 11], [11, 103]], [[45, 12], [11, 103]]]
# [[[57, 0], [1, 113]], [[33, 24], [7, 107]], [[50, 7], [23, 91]]]
# [[[58, 0], [5, 111]], [[46, 12], [13, 103]], [[41, 17], [11, 105]]]
# [[[58, 0], [2, 114]], [[43, 15], [10, 106]], [[48, 10], [13, 103]]]
# [[[57, 0], [5, 109]], [[45, 12], [5, 109]], [[50, 7], [9, 105]]]
# [[[57, 0], [0, 114]], [[42, 15], [9, 105]], [[48, 9], [15, 99]]]
# [[[57, 0], [0, 114]], [[41, 16], [9, 105]], [[48, 9], [16, 98]]]
# [[[58, 0], [3, 113]], [[42, 16], [13, 103]], [[44, 14], [14, 102]]]
# [[[58, 0], [2, 114]], [[48, 10], [12, 104]], [[45, 13], [9, 107]]]
# [[[57, 0], [2, 112]], [[41, 16], [9, 105]], [[47, 10], [15, 99]]]
# [[[57, 0], [2, 112]], [[47, 10], [8, 106]], [[49, 8], [8, 106]]]
# [[[57, 0], [1, 113]], [[42, 15], [14, 100]], [[43, 14], [14, 100]]]
# [[[58, 0], [2, 114]], [[39, 19], [8, 108]], [[50, 8], [17, 99]]]
# [[[58, 0], [2, 114]], [[41, 17], [10, 106]], [[48, 10], [15, 101]]]
# [[[57, 0], [4, 110]], [[41, 16], [11, 103]], [[44, 13], [14, 100]]]
# [[[57, 0], [1, 113]], [[46, 11], [12, 102]], [[44, 13], [11, 103]]]
# [[[57, 0], [0, 114]], [[44, 13], [12, 102]], [[45, 12], [13, 101]]]
# [[[58, 0], [2, 114]], [[43, 15], [8, 108]], [[49, 9], [14, 102]]]
# [[[58, 0], [3, 113]], [[39, 19], [8, 108]], [[48, 10], [18, 98]]]
# [[[57, 0], [2, 112]], [[42, 15], [4, 110]], [[52, 5], [14, 100]]]
# [[[57, 0], [0, 114]], [[48, 9], [14, 100]], [[43, 14], [9, 105]]]
# [[[57, 0], [1, 113]], [[43, 14], [9, 105]], [[48, 9], [13, 101]]]
# [[[58, 0], [1, 115]], [[49, 9], [10, 106]], [[48, 10], [8, 108]]]
# [[[58, 0], [3, 113]], [[40, 18], [7, 109]], [[50, 8], [16, 100]]]
# [[[57, 0], [1, 113]], [[43, 14], [8, 106]], [[49, 8], [13, 101]]]
# [[[57, 0], [1, 113]], [[37, 20], [12, 102]], [[44, 13], [20, 94]]]
# [[[57, 0], [2, 112]], [[45, 12], [15, 99]], [[42, 15], [10, 104]]]
# [[[58, 0], [0, 116]], [[48, 10], [10, 106]], [[48, 10], [10, 106]]]
# [[[58, 0], [0, 116]], [[43, 15], [9, 107]], [[49, 9], [15, 101]]]
# [[[57, 0], [2, 112]], [[42, 15], [9, 105]], [[47, 10], [14, 100]]]
# [[[57, 0], [3, 111]], [[40, 17], [11, 103]], [[45, 12], [15, 99]]]
# [[[57, 0], [1, 113]], [[46, 11], [11, 103]], [[45, 12], [11, 103]]]
# [[[58, 0], [1, 115]], [[41, 17], [19, 97]], [[39, 19], [16, 100]]]
# [[[58, 0], [0, 116]], [[40, 18], [7, 109]], [[51, 7], [18, 98]]]
# [[[57, 0], [2, 112]], [[42, 15], [3, 111]], [[53, 4], [14, 100]]]
# [[[57, 0], [1, 113]], [[40, 17], [4, 110]], [[52, 5], [17, 97]]]
# [[[57, 0], [2, 112]], [[42, 15], [12, 102]], [[45, 12], [13, 101]]]
# [[[58, 0], [1, 115]], [[46, 12], [8, 108]], [[50, 8], [11, 105]]]
# [[[58, 0], [1, 115]], [[45, 13], [9, 107]], [[48, 10], [13, 103]]]
# [[[57, 0], [1, 113]], [[40, 17], [12, 102]], [[45, 12], [16, 98]]]
# [[[57, 0], [5, 109]], [[42, 15], [6, 108]], [[49, 8], [12, 102]]]
# [[[57, 0], [4, 110]], [[39, 18], [8, 106]], [[48, 9], [15, 99]]]
# [[[58, 0], [1, 115]], [[44, 14], [12, 104]], [[46, 12], [13, 103]]]
# [[[58, 0], [3, 113]], [[42, 16], [10, 106]], [[46, 12], [15, 101]]]
# [[[57, 0], [1, 113]], [[43, 14], [14, 100]], [[43, 14], [13, 101]]]
# [[[57, 0], [1, 113]], [[42, 15], [12, 102]], [[44, 13], [15, 99]]]
# [[[57, 0], [1, 113]], [[47, 10], [6, 108]], [[50, 7], [10, 104]]]
# [[[58, 0], [0, 116]], [[47, 11], [10, 106]], [[48, 10], [11, 105]]]
# [[[58, 0], [2, 114]], [[42, 16], [13, 103]], [[44, 14], [15, 101]]]
# [[[57, 0], [1, 113]], [[45, 12], [6, 108]], [[50, 7], [12, 102]]]
# [[[57, 0], [2, 112]], [[43, 14], [8, 106]], [[49, 8], [12, 102]]]
# [[[57, 0], [4, 110]], [[41, 16], [14, 100]], [[42, 15], [13, 101]]]
# [[[58, 0], [1, 115]], [[46, 12], [12, 104]], [[45, 13], [12, 104]]]
# [[[58, 0], [1, 115]], [[45, 13], [11, 105]], [[47, 11], [12, 104]]]
# [[[57, 0], [1, 113]], [[41, 16], [9, 105]], [[48, 9], [15, 99]]]
# [[[57, 0], [2, 112]], [[42, 15], [11, 103]], [[45, 12], [14, 100]]]
# [[[57, 0], [3, 111]], [[41, 16], [8, 106]], [[47, 10], [15, 99]]]
# [[[58, 0], [3, 113]], [[47, 11], [9, 107]], [[47, 11], [10, 106]]]
# [[[58, 0], [2, 114]], [[43, 15], [12, 104]], [[45, 13], [14, 102]]]
# [[[57, 0], [1, 113]], [[43, 14], [12, 102]], [[45, 12], [13, 101]]]
# [[[57, 0], [3, 111]], [[40, 17], [5, 109]], [[51, 6], [15, 99]]]
# [[[57, 0], [2, 112]], [[44, 13], [13, 101]], [[44, 13], [11, 103]]]
# [[[58, 0], [2, 114]], [[45, 13], [10, 106]], [[48, 10], [11, 105]]]
# [[[58, 0], [2, 114]], [[46, 12], [5, 111]], [[52, 6], [11, 105]]]
# [[[57, 0], [3, 111]], [[35, 22], [6, 108]], [[49, 8], [21, 93]]]
# [[[57, 0], [0, 114]], [[37, 20], [13, 101]], [[44, 13], [20, 94]]]
# [[[57, 0], [2, 112]], [[47, 10], [10, 104]], [[46, 11], [9, 105]]]
# [[[58, 0], [1, 115]], [[40, 18], [12, 104]], [[45, 13], [18, 98]]]
# [[[58, 0], [2, 114]], [[38, 20], [12, 104]], [[46, 12], [18, 98]]]
# [[[57, 0], [0, 114]], [[46, 11], [6, 108]], [[51, 6], [11, 103]]]
# [[[57, 0], [3, 111]], [[43, 14], [9, 105]], [[46, 11], [13, 101]]]
# [[[57, 0], [2, 112]], [[45, 12], [11, 103]], [[45, 12], [11, 103]]]
# [[[58, 0], [1, 115]], [[43, 15], [9, 107]], [[49, 9], [14, 102]]]
# [[[58, 0], [1, 115]], [[45, 13], [10, 106]], [[48, 10], [12, 104]]]
# [[[57, 0], [2, 112]], [[42, 15], [3, 111]], [[53, 4], [14, 100]]]
# [[[57, 0], [3, 111]], [[45, 12], [12, 102]], [[44, 13], [10, 104]]]
# [[[57, 0], [4, 110]], [[43, 14], [12, 102]], [[44, 13], [11, 103]]]
# [[[58, 0], [2, 114]], [[41, 17], [11, 105]], [[46, 12], [16, 100]]]
# [[[58, 0], [2, 114]], [[39, 19], [8, 108]], [[50, 8], [17, 99]]]
# [[[57, 0], [4, 110]], [[43, 14], [15, 99]], [[40, 17], [12, 102]]]
# [[[57, 0], [0, 114]], [[41, 16], [10, 104]], [[47, 10], [16, 98]]]
# [[[57, 0], [2, 112]], [[46, 11], [11, 103]], [[46, 11], [9, 105]]]
# [[[58, 0], [1, 115]], [[48, 10], [10, 106]], [[48, 10], [9, 107]]]
# [[[58, 0], [1, 115]], [[42, 16], [12, 104]], [[46, 12], [15, 101]]]
# [[[57, 0], [3, 111]], [[46, 11], [11, 103]], [[44, 13], [10, 104]]]
# [[[57, 0], [2, 112]], [[40, 17], [9, 105]], [[47, 10], [16, 98]]]
# [[[57, 0], [0, 114]], [[40, 17], [9, 105]], [[48, 9], [17, 97]]]
# [[[58, 0], [2, 114]], [[40, 18], [9, 107]], [[49, 9], [16, 100]]]
# [[[58, 0], [1, 115]], [[45, 13], [13, 103]], [[45, 13], [12, 104]]]
# [[[57, 0], [1, 113]], [[38, 19], [10, 104]], [[47, 10], [18, 96]]]
# [[[57, 0], [3, 111]], [[39, 18], [7, 107]], [[48, 9], [17, 97]]]
#
# [[[61, 0], [0, 122]], [[53, 8], [7, 115]], [[54, 7], [8, 114]]]
# [[[61, 0], [0, 122]], [[47, 14], [5, 117]], [[56, 5], [14, 108]]]
# [[[61, 0], [0, 122]], [[49, 12], [8, 114]], [[53, 8], [12, 110]]]
# [[[61, 0], [0, 122]], [[48, 13], [4, 118]], [[57, 4], [13, 109]]]
# [[[62, 0], [1, 123]], [[51, 11], [5, 119]], [[57, 5], [10, 114]]]
# [[[61, 0], [0, 122]], [[47, 14], [7, 115]], [[54, 7], [14, 108]]]
# [[[61, 0], [1, 121]], [[52, 9], [5, 117]], [[56, 5], [8, 114]]]
# [[[61, 0], [1, 121]], [[49, 12], [5, 117]], [[56, 5], [11, 111]]]
# [[[61, 0], [0, 122]], [[51, 10], [4, 118]], [[57, 4], [10, 112]]]
# [[[62, 0], [0, 124]], [[51, 11], [6, 118]], [[56, 6], [11, 113]]]
# [[[61, 0], [1, 121]], [[46, 15], [5, 117]], [[56, 5], [14, 108]]]
# [[[61, 0], [0, 122]], [[50, 11], [11, 111]], [[50, 11], [11, 111]]]
# [[[61, 0], [0, 122]], [[50, 11], [3, 119]], [[58, 3], [11, 111]]]
# [[[61, 0], [1, 121]], [[45, 16], [8, 114]], [[53, 8], [15, 107]]]
# [[[62, 0], [0, 124]], [[48, 14], [7, 117]], [[55, 7], [14, 110]]]
# [[[61, 0], [0, 122]], [[55, 6], [3, 119]], [[58, 3], [6, 116]]]
# [[[61, 0], [2, 120]], [[46, 15], [5, 117]], [[56, 5], [13, 109]]]
# [[[61, 0], [1, 121]], [[54, 7], [4, 118]], [[57, 4], [6, 116]]]
# [[[61, 0], [0, 122]], [[48, 13], [10, 112]], [[51, 10], [13, 109]]]
# [[[62, 0], [0, 124]], [[55, 7], [6, 118]], [[56, 6], [7, 117]]]
# [[[61, 0], [0, 122]], [[49, 12], [6, 116]], [[55, 6], [12, 110]]]
# [[[61, 0], [2, 120]], [[45, 16], [9, 113]], [[52, 9], [14, 108]]]
# [[[61, 0], [0, 122]], [[52, 9], [3, 119]], [[58, 3], [9, 113]]]
# [[[61, 0], [0, 122]], [[48, 13], [9, 113]], [[52, 9], [13, 109]]]
# [[[62, 0], [0, 124]], [[51, 11], [6, 118]], [[56, 6], [11, 113]]]
# [[[61, 0], [1, 121]], [[54, 7], [3, 119]], [[58, 3], [6, 116]]]
# [[[61, 0], [0, 122]], [[45, 16], [6, 116]], [[55, 6], [16, 106]]]
# [[[61, 0], [0, 122]], [[51, 10], [6, 116]], [[55, 6], [10, 112]]]
# [[[61, 0], [2, 120]], [[49, 12], [5, 117]], [[56, 5], [10, 112]]]
# [[[62, 0], [0, 124]], [[49, 13], [2, 122]], [[60, 2], [13, 111]]]
# [[[61, 0], [3, 119]], [[47, 14], [8, 114]], [[53, 8], [11, 111]]]
# [[[61, 0], [1, 121]], [[45, 16], [4, 118]], [[57, 4], [15, 107]]]
# [[[61, 0], [1, 121]], [[47, 14], [8, 114]], [[53, 8], [13, 109]]]
# [[[61, 0], [0, 122]], [[53, 8], [2, 120]], [[59, 2], [8, 114]]]
# [[[62, 0], [1, 123]], [[56, 6], [10, 114]], [[52, 10], [5, 119]]]
# [[[61, 0], [0, 122]], [[48, 13], [7, 115]], [[54, 7], [13, 109]]]
# [[[61, 0], [0, 122]], [[49, 12], [6, 116]], [[55, 6], [12, 110]]]
# [[[61, 0], [0, 122]], [[50, 11], [5, 117]], [[56, 5], [11, 111]]]
# [[[61, 0], [1, 121]], [[48, 13], [4, 118]], [[57, 4], [12, 110]]]
# [[[62, 0], [1, 123]], [[51, 11], [3, 121]], [[59, 3], [10, 114]]]
# [[[61, 0], [0, 122]], [[46, 15], [6, 116]], [[55, 6], [15, 107]]]
# [[[61, 0], [0, 122]], [[51, 10], [7, 115]], [[54, 7], [10, 112]]]
# [[[61, 0], [3, 119]], [[48, 13], [8, 114]], [[53, 8], [10, 112]]]
# [[[61, 0], [0, 122]], [[54, 7], [7, 115]], [[54, 7], [7, 115]]]
# [[[62, 0], [1, 123]], [[59, 3], [15, 109]], [[47, 15], [2, 122]]]
# [[[61, 0], [0, 122]], [[52, 9], [7, 115]], [[54, 7], [9, 113]]]
# [[[61, 0], [2, 120]], [[44, 17], [3, 119]], [[58, 3], [15, 107]]]
# [[[61, 0], [0, 122]], [[52, 9], [6, 116]], [[55, 6], [9, 113]]]
# [[[61, 0], [0, 122]], [[54, 7], [6, 116]], [[55, 6], [7, 115]]]
# [[[62, 0], [0, 124]], [[47, 15], [5, 119]], [[57, 5], [15, 109]]]
# [[[61, 0], [0, 122]], [[54, 7], [1, 121]], [[60, 1], [7, 115]]]
# [[[61, 0], [0, 122]], [[50, 11], [10, 112]], [[51, 10], [11, 111]]]
# [[[61, 0], [0, 122]], [[51, 10], [6, 116]], [[55, 6], [10, 112]]]
# [[[61, 0], [3, 119]], [[44, 17], [9, 113]], [[52, 9], [14, 108]]]
# [[[62, 0], [1, 123]], [[54, 8], [7, 117]], [[55, 7], [7, 117]]]
# [[[61, 0], [0, 122]], [[50, 11], [8, 114]], [[53, 8], [11, 111]]]
# [[[61, 0], [1, 121]], [[48, 13], [6, 116]], [[55, 6], [12, 110]]]
# [[[61, 0], [0, 122]], [[51, 10], [11, 111]], [[50, 11], [10, 112]]]
# [[[61, 0], [1, 121]], [[49, 12], [5, 117]], [[56, 5], [11, 111]]]
# [[[62, 0], [2, 122]], [[51, 11], [7, 117]], [[55, 7], [9, 115]]]
# [[[61, 0], [0, 122]], [[47, 14], [6, 116]], [[55, 6], [14, 108]]]
# [[[61, 0], [0, 122]], [[54, 7], [10, 112]], [[51, 10], [7, 115]]]
# [[[61, 0], [1, 121]], [[51, 10], [10, 112]], [[51, 10], [9, 113]]]
# [[[61, 0], [1, 121]], [[50, 11], [10, 112]], [[51, 10], [10, 112]]]
# [[[62, 0], [0, 124]], [[54, 8], [9, 115]], [[53, 9], [8, 116]]]
# [[[61, 0], [1, 121]], [[51, 10], [8, 114]], [[53, 8], [9, 113]]]
# [[[61, 0], [0, 122]], [[47, 14], [6, 116]], [[55, 6], [14, 108]]]
# [[[61, 0], [1, 121]], [[43, 18], [3, 119]], [[58, 3], [17, 105]]]
# [[[61, 0], [1, 121]], [[53, 8], [1, 121]], [[60, 1], [7, 115]]]
# [[[62, 0], [0, 124]], [[51, 11], [8, 116]], [[54, 8], [11, 113]]]
# [[[61, 0], [1, 121]], [[49, 12], [9, 113]], [[52, 9], [11, 111]]]
# [[[61, 0], [0, 122]], [[47, 14], [3, 119]], [[58, 3], [14, 108]]]
# [[[61, 0], [0, 122]], [[49, 12], [5, 117]], [[56, 5], [12, 110]]]
# [[[61, 0], [1, 121]], [[48, 13], [7, 115]], [[54, 7], [12, 110]]]
# [[[62, 0], [2, 122]], [[53, 9], [3, 121]], [[59, 3], [7, 117]]]
# [[[61, 0], [0, 122]], [[53, 8], [4, 118]], [[57, 4], [8, 114]]]
# [[[61, 0], [0, 122]], [[49, 12], [4, 118]], [[57, 4], [12, 110]]]
# [[[61, 0], [1, 121]], [[47, 14], [8, 114]], [[53, 8], [13, 109]]]
# [[[61, 0], [0, 122]], [[47, 14], [5, 117]], [[56, 5], [14, 108]]]
# [[[62, 0], [0, 124]], [[51, 11], [10, 114]], [[52, 10], [11, 113]]]
# [[[61, 0], [2, 120]], [[52, 9], [4, 118]], [[57, 4], [7, 115]]]
# [[[61, 0], [0, 122]], [[52, 9], [5, 117]], [[56, 5], [9, 113]]]
# [[[61, 0], [0, 122]], [[46, 15], [1, 121]], [[60, 1], [15, 107]]]
# [[[61, 0], [1, 121]], [[47, 14], [7, 115]], [[54, 7], [13, 109]]]
# [[[62, 0], [0, 124]], [[53, 9], [3, 121]], [[59, 3], [9, 115]]]
# [[[61, 0], [0, 122]], [[47, 14], [5, 117]], [[56, 5], [14, 108]]]
# [[[61, 0], [0, 122]], [[47, 14], [7, 115]], [[54, 7], [14, 108]]]
# [[[61, 0], [0, 122]], [[52, 9], [9, 113]], [[52, 9], [9, 113]]]
# [[[61, 0], [2, 120]], [[52, 9], [2, 120]], [[59, 2], [7, 115]]]
# [[[62, 0], [2, 122]], [[54, 8], [4, 120]], [[58, 4], [6, 118]]]
# [[[61, 0], [0, 122]], [[50, 11], [3, 119]], [[58, 3], [11, 111]]]
# [[[61, 0], [0, 122]], [[46, 15], [5, 117]], [[56, 5], [15, 107]]]
# [[[61, 0], [1, 121]], [[51, 10], [7, 115]], [[54, 7], [9, 113]]]
# [[[61, 0], [1, 121]], [[49, 12], [12, 110]], [[49, 12], [11, 111]]]
# [[[62, 0], [0, 124]], [[53, 9], [6, 118]], [[56, 6], [9, 115]]]
# [[[61, 0], [2, 120]], [[44, 17], [4, 118]], [[57, 4], [15, 107]]]
# [[[61, 0], [1, 121]], [[49, 12], [8, 114]], [[53, 8], [11, 111]]]
# [[[61, 0], [0, 122]], [[54, 7], [5, 117]], [[56, 5], [7, 115]]]
# [[[61, 0], [0, 122]], [[48, 13], [7, 115]], [[54, 7], [13, 109]]]
# [[[62, 0], [0, 124]], [[51, 11], [5, 119]], [[57, 5], [11, 113]]]
# [[[61, 0], [0, 122]], [[46, 15], [4, 118]], [[57, 4], [15, 107]]]
# [[[61, 0], [2, 120]], [[47, 14], [11, 111]], [[50, 11], [12, 110]]]
# [[[61, 0], [0, 122]], [[50, 11], [3, 119]], [[58, 3], [11, 111]]]
# [[[61, 0], [0, 122]], [[52, 9], [4, 118]], [[57, 4], [9, 113]]]
# [[[62, 0], [1, 123]], [[54, 8], [2, 122]], [[60, 2], [7, 117]]]
# [[[61, 0], [0, 122]], [[50, 11], [3, 119]], [[58, 3], [11, 111]]]
# [[[61, 0], [2, 120]], [[46, 15], [6, 116]], [[55, 6], [13, 109]]]
# [[[61, 0], [0, 122]], [[49, 12], [5, 117]], [[56, 5], [12, 110]]]
# [[[61, 0], [1, 121]], [[48, 13], [6, 116]], [[55, 6], [12, 110]]]
# [[[62, 0], [0, 124]], [[50, 12], [4, 120]], [[58, 4], [12, 112]]]
# [[[61, 0], [0, 122]], [[50, 11], [3, 119]], [[58, 3], [11, 111]]]
# [[[61, 0], [2, 120]], [[50, 11], [4, 118]], [[57, 4], [9, 113]]]
# [[[61, 0], [1, 121]], [[46, 15], [9, 113]], [[52, 9], [14, 108]]]
# [[[61, 0], [0, 122]], [[51, 10], [9, 113]], [[52, 9], [10, 112]]]
# [[[62, 0], [0, 124]], [[52, 10], [7, 117]], [[55, 7], [10, 114]]]
# [[[61, 0], [0, 122]], [[46, 15], [5, 117]], [[56, 5], [15, 107]]]
# [[[61, 0], [0, 122]], [[47, 14], [3, 119]], [[58, 3], [14, 108]]]
# [[[61, 0], [0, 122]], [[53, 8], [5, 117]], [[56, 5], [8, 114]]]
# [[[61, 0], [3, 119]], [[52, 9], [9, 113]], [[52, 9], [6, 116]]]
# [[[62, 0], [0, 124]], [[50, 12], [5, 119]], [[57, 5], [12, 112]]]
# [[[61, 0], [2, 120]], [[49, 12], [4, 118]], [[57, 4], [10, 112]]]
# [[[61, 0], [1, 121]], [[46, 15], [4, 118]], [[57, 4], [14, 108]]]
# [[[61, 0], [0, 122]], [[51, 10], [10, 112]], [[51, 10], [10, 112]]]
# [[[61, 0], [0, 122]], [[50, 11], [6, 116]], [[55, 6], [11, 111]]]
# [[[62, 0], [3, 121]], [[49, 13], [6, 118]], [[56, 6], [10, 114]]]
# [[[61, 0], [1, 121]], [[48, 13], [3, 119]], [[58, 3], [12, 110]]]
# [[[61, 0], [0, 122]], [[50, 11], [11, 111]], [[50, 11], [11, 111]]]
# [[[61, 0], [0, 122]], [[46, 15], [4, 118]], [[57, 4], [15, 107]]]
# [[[61, 0], [0, 122]], [[52, 9], [7, 115]], [[54, 7], [9, 113]]]
# [[[62, 0], [1, 123]], [[48, 14], [8, 116]], [[54, 8], [13, 111]]]
# [[[61, 0], [0, 122]], [[45, 16], [5, 117]], [[56, 5], [16, 106]]]
# [[[61, 0], [2, 120]], [[50, 11], [6, 116]], [[55, 6], [9, 113]]]
# [[[61, 0], [0, 122]], [[50, 11], [2, 120]], [[59, 2], [11, 111]]]
# [[[61, 0], [1, 121]], [[50, 11], [5, 117]], [[56, 5], [10, 112]]]
# [[[57, 0], [6, 108]], [[39, 18], [9, 105]], [[45, 12], [15, 99]]]
# [[[57, 0], [4, 110]], [[39, 18], [12, 102]], [[45, 12], [14, 100]]]
# [[[57, 0], [6, 108]], [[38, 19], [11, 103]], [[45, 12], [14, 100]]]
# [[[57, 0], [4, 110]], [[42, 15], [20, 94]], [[37, 20], [11, 103]]]
# [[[56, 0], [2, 110]], [[42, 14], [10, 102]], [[46, 10], [12, 100]]]
# [[[57, 0], [3, 111]], [[40, 17], [12, 102]], [[44, 13], [15, 99]]]
# [[[57, 0], [4, 110]], [[43, 14], [11, 103]], [[45, 12], [11, 103]]]
# [[[57, 0], [4, 110]], [[43, 14], [10, 104]], [[47, 10], [10, 104]]]
# [[[57, 0], [4, 110]], [[38, 19], [9, 105]], [[46, 11], [17, 97]]]
# [[[56, 0], [2, 110]], [[40, 16], [9, 103]], [[47, 9], [14, 98]]]
# [[[57, 0], [4, 110]], [[42, 15], [8, 106]], [[49, 8], [11, 103]]]
# [[[57, 0], [7, 107]], [[35, 22], [4, 110]], [[52, 5], [16, 98]]]
# [[[57, 0], [1, 113]], [[41, 16], [12, 102]], [[44, 13], [16, 98]]]
# [[[57, 0], [5, 109]], [[42, 15], [10, 104]], [[45, 12], [12, 102]]]
# [[[56, 0], [5, 107]], [[41, 15], [8, 104]], [[48, 8], [10, 102]]]
# [[[57, 0], [3, 111]], [[43, 14], [5, 109]], [[50, 7], [13, 101]]]
# [[[57, 0], [7, 107]], [[28, 29], [10, 104]], [[46, 11], [23, 91]]]
# [[[57, 0], [3, 111]], [[42, 15], [5, 109]], [[51, 6], [13, 101]]]
# [[[57, 0], [3, 111]], [[44, 13], [13, 101]], [[44, 13], [10, 104]]]
# [[[56, 0], [4, 108]], [[42, 14], [6, 106]], [[50, 6], [10, 102]]]
# [[[57, 0], [3, 111]], [[42, 15], [9, 105]], [[47, 10], [13, 101]]]
# [[[57, 0], [6, 108]], [[39, 18], [9, 105]], [[47, 10], [13, 101]]]
# [[[57, 0], [2, 112]], [[38, 19], [14, 100]], [[43, 14], [17, 97]]]
# [[[57, 0], [11, 103]], [[36, 21], [9, 105]], [[45, 12], [13, 101]]]
# [[[56, 0], [2, 110]], [[41, 15], [14, 98]], [[41, 15], [14, 98]]]
# [[[57, 0], [2, 112]], [[44, 13], [12, 102]], [[44, 13], [12, 102]]]
# [[[57, 0], [4, 110]], [[37, 20], [8, 106]], [[48, 9], [17, 97]]]
# [[[57, 0], [8, 106]], [[37, 20], [11, 103]], [[45, 12], [13, 101]]]
# [[[57, 0], [3, 111]], [[36, 21], [10, 104]], [[47, 10], [18, 96]]]
# [[[56, 0], [9, 103]], [[41, 15], [13, 99]], [[41, 15], [8, 104]]]
# [[[57, 0], [4, 110]], [[42, 15], [12, 102]], [[44, 13], [12, 102]]]
# [[[57, 0], [5, 109]], [[38, 19], [12, 102]], [[43, 14], [16, 98]]]
# [[[57, 0], [3, 111]], [[39, 18], [11, 103]], [[46, 11], [15, 99]]]
# [[[57, 0], [4, 110]], [[43, 14], [12, 102]], [[45, 12], [10, 104]]]
# [[[56, 0], [6, 106]], [[37, 19], [5, 107]], [[50, 6], [14, 98]]]
# [[[57, 0], [10, 104]], [[42, 15], [7, 107]], [[45, 12], [10, 104]]]
# [[[57, 0], [3, 111]], [[38, 19], [4, 110]], [[53, 4], [16, 98]]]
# [[[57, 0], [2, 112]], [[45, 12], [9, 105]], [[47, 10], [11, 103]]]
# [[[57, 0], [4, 110]], [[36, 21], [10, 104]], [[46, 11], [18, 96]]]
# [[[56, 0], [4, 108]], [[41, 15], [8, 104]], [[47, 9], [12, 100]]]
# [[[57, 0], [3, 111]], [[46, 11], [9, 105]], [[47, 10], [9, 105]]]
# [[[57, 0], [4, 110]], [[40, 17], [19, 95]], [[38, 19], [13, 101]]]
# [[[57, 0], [2, 112]], [[41, 16], [4, 110]], [[52, 5], [15, 99]]]
# [[[57, 0], [5, 109]], [[39, 18], [9, 105]], [[47, 10], [14, 100]]]
# [[[56, 0], [5, 107]], [[39, 17], [7, 105]], [[48, 8], [13, 99]]]
# [[[57, 0], [6, 108]], [[39, 18], [12, 102]], [[44, 13], [13, 101]]]
# [[[57, 0], [6, 108]], [[38, 19], [8, 106]], [[47, 10], [15, 99]]]
# [[[57, 0], [6, 108]], [[37, 20], [14, 100]], [[42, 15], [15, 99]]]
# [[[57, 0], [4, 110]], [[43, 14], [8, 106]], [[47, 10], [12, 102]]]
# [[[56, 0], [2, 110]], [[38, 18], [8, 104]], [[47, 9], [17, 95]]]
# [[[57, 0], [5, 109]], [[41, 16], [9, 105]], [[46, 11], [13, 101]]]
# [[[57, 0], [6, 108]], [[38, 19], [12, 102]], [[45, 12], [13, 101]]]
# [[[57, 0], [3, 111]], [[36, 21], [12, 102]], [[45, 12], [18, 96]]]
# [[[57, 0], [3, 111]], [[38, 19], [12, 102]], [[45, 12], [16, 98]]]
# [[[56, 0], [5, 107]], [[39, 17], [8, 104]], [[44, 12], [16, 96]]]
# [[[57, 0], [6, 108]], [[42, 15], [9, 105]], [[46, 11], [11, 103]]]
# [[[57, 0], [4, 110]], [[46, 11], [13, 101]], [[42, 15], [9, 105]]]
# [[[57, 0], [1, 113]], [[39, 18], [5, 109]], [[52, 5], [17, 97]]]
# [[[57, 0], [5, 109]], [[38, 19], [12, 102]], [[45, 12], [14, 100]]]
# [[[56, 0], [2, 110]], [[30, 26], [10, 102]], [[46, 10], [24, 88]]]
# [[[57, 0], [3, 111]], [[44, 13], [14, 100]], [[42, 15], [11, 103]]]
# [[[57, 0], [7, 107]], [[38, 19], [10, 104]], [[46, 11], [13, 101]]]
# [[[57, 0], [4, 110]], [[42, 15], [8, 106]], [[48, 9], [12, 102]]]
# [[[57, 0], [5, 109]], [[36, 21], [4, 110]], [[52, 5], [17, 97]]]
# [[[56, 0], [1, 111]], [[39, 17], [15, 97]], [[41, 15], [16, 96]]]
# [[[57, 0], [5, 109]], [[36, 21], [6, 108]], [[49, 8], [18, 96]]]
# [[[57, 0], [3, 111]], [[37, 20], [14, 100]], [[43, 14], [17, 97]]]
# [[[57, 0], [4, 110]], [[44, 13], [8, 106]], [[47, 10], [11, 103]]]
# [[[57, 0], [6, 108]], [[34, 23], [8, 106]], [[49, 8], [17, 97]]]
# [[[56, 0], [8, 104]], [[34, 22], [12, 100]], [[42, 14], [16, 96]]]
# [[[57, 0], [2, 112]], [[43, 14], [10, 104]], [[47, 10], [12, 102]]]
# [[[57, 0], [6, 108]], [[35, 22], [6, 108]], [[51, 6], [16, 98]]]
# [[[57, 0], [5, 109]], [[36, 21], [11, 103]], [[46, 11], [16, 98]]]
# [[[57, 0], [4, 110]], [[36, 21], [6, 108]], [[50, 7], [18, 96]]]
# [[[56, 0], [4, 108]], [[41, 15], [16, 96]], [[37, 19], [14, 98]]]
# [[[57, 0], [7, 107]], [[39, 18], [2, 112]], [[54, 3], [12, 102]]]
# [[[57, 0], [8, 106]], [[38, 19], [14, 100]], [[40, 17], [14, 100]]]
# [[[57, 0], [2, 112]], [[41, 16], [11, 103]], [[45, 12], [15, 99]]]
# [[[57, 0], [4, 110]], [[36, 21], [13, 101]], [[44, 13], [17, 97]]]
# [[[56, 0], [7, 105]], [[38, 18], [7, 105]], [[48, 8], [12, 100]]]
# [[[57, 0], [2, 112]], [[33, 24], [11, 103]], [[46, 11], [22, 92]]]
# [[[57, 0], [10, 104]], [[39, 18], [11, 103]], [[42, 15], [12, 102]]]
# [[[57, 0], [4, 110]], [[41, 16], [9, 105]], [[48, 9], [12, 102]]]
# [[[57, 0], [2, 112]], [[37, 20], [6, 108]], [[51, 6], [18, 96]]]
# [[[56, 0], [4, 108]], [[34, 22], [6, 106]], [[50, 6], [18, 94]]]
# [[[57, 0], [7, 107]], [[43, 14], [9, 105]], [[47, 10], [8, 106]]]
# [[[57, 0], [6, 108]], [[34, 23], [10, 104]], [[45, 12], [19, 95]]]
# [[[57, 0], [2, 112]], [[43, 14], [6, 108]], [[51, 6], [12, 102]]]
# [[[57, 0], [6, 108]], [[34, 23], [10, 104]], [[46, 11], [18, 96]]]
# [[[56, 0], [1, 111]], [[39, 17], [8, 104]], [[47, 9], [17, 95]]]
# [[[57, 0], [3, 111]], [[37, 20], [9, 105]], [[48, 9], [17, 97]]]
# [[[57, 0], [7, 107]], [[35, 22], [12, 102]], [[44, 13], [16, 98]]]
# [[[57, 0], [4, 110]], [[40, 17], [11, 103]], [[45, 12], [14, 100]]]
# [[[57, 0], [7, 107]], [[39, 18], [5, 109]], [[50, 7], [13, 101]]]
# [[[56, 0], [0, 112]], [[46, 10], [7, 105]], [[49, 7], [10, 102]]]
# [[[57, 0], [6, 108]], [[42, 15], [13, 101]], [[43, 14], [10, 104]]]
# [[[57, 0], [6, 108]], [[36, 21], [8, 106]], [[48, 9], [16, 98]]]
# [[[57, 0], [3, 111]], [[43, 14], [7, 107]], [[49, 8], [12, 102]]]
# [[[57, 0], [3, 111]], [[35, 22], [7, 107]], [[49, 8], [20, 94]]]
# [[[56, 0], [5, 107]], [[39, 17], [15, 97]], [[41, 15], [12, 100]]]
# [[[57, 0], [3, 111]], [[40, 17], [7, 107]], [[50, 7], [14, 100]]]
# [[[57, 0], [5, 109]], [[36, 21], [11, 103]], [[46, 11], [16, 98]]]
# [[[57, 0], [1, 113]], [[39, 18], [11, 103]], [[46, 11], [17, 97]]]
# [[[57, 0], [5, 109]], [[37, 20], [3, 111]], [[51, 6], [18, 96]]]
# [[[56, 0], [10, 102]], [[39, 17], [12, 100]], [[41, 15], [10, 102]]]
# [[[57, 0], [10, 104]], [[45, 12], [16, 98]], [[36, 21], [7, 107]]]
# [[[57, 0], [5, 109]], [[35, 22], [5, 109]], [[50, 7], [19, 95]]]
# [[[57, 0], [3, 111]], [[40, 17], [13, 101]], [[44, 13], [14, 100]]]
# [[[57, 0], [2, 112]], [[43, 14], [8, 106]], [[49, 8], [12, 102]]]
# [[[56, 0], [5, 107]], [[36, 20], [7, 105]], [[49, 7], [15, 97]]]
# [[[57, 0], [8, 106]], [[38, 19], [9, 105]], [[47, 10], [12, 102]]]
# [[[57, 0], [4, 110]], [[44, 13], [10, 104]], [[44, 13], [12, 102]]]
# [[[57, 0], [3, 111]], [[40, 17], [10, 104]], [[47, 10], [14, 100]]]
# [[[57, 0], [5, 109]], [[32, 25], [4, 110]], [[53, 4], [20, 94]]]
# [[[56, 0], [2, 110]], [[47, 9], [12, 100]], [[42, 14], [9, 103]]]
# [[[57, 0], [2, 112]], [[44, 13], [12, 102]], [[45, 12], [11, 103]]]
# [[[57, 0], [7, 107]], [[38, 19], [14, 100]], [[38, 19], [17, 97]]]
# [[[57, 0], [3, 111]], [[40, 17], [7, 107]], [[50, 7], [14, 100]]]
# [[[57, 0], [6, 108]], [[37, 20], [11, 103]], [[45, 12], [15, 99]]]
# [[[56, 0], [7, 105]], [[34, 22], [8, 104]], [[47, 9], [16, 96]]]
# [[[57, 0], [1, 113]], [[43, 14], [8, 106]], [[48, 9], [14, 100]]]
# [[[57, 0], [11, 103]], [[36, 21], [3, 111]], [[50, 7], [14, 100]]]
# [[[57, 0], [6, 108]], [[36, 21], [13, 101]], [[44, 13], [15, 99]]]
# [[[57, 0], [3, 111]], [[37, 20], [12, 102]], [[44, 13], [18, 96]]]
# [[[56, 0], [5, 107]], [[40, 16], [10, 102]], [[46, 10], [11, 101]]]
# [[[57, 0], [6, 108]], [[36, 21], [11, 103]], [[44, 13], [17, 97]]]
# [[[57, 0], [4, 110]], [[47, 10], [14, 100]], [[42, 15], [7, 107]]]
# [[[57, 0], [2, 112]], [[38, 19], [8, 106]], [[49, 8], [17, 97]]]
# [[[57, 0], [4, 110]], [[39, 18], [6, 108]], [[50, 7], [15, 99]]]
# [[[56, 0], [4, 108]], [[38, 18], [15, 97]], [[40, 16], [15, 97]]]
# [[[57, 0], [2, 112]], [[37, 20], [14, 100]], [[43, 14], [18, 96]]]
# [[[57, 0], [6, 108]], [[43, 14], [7, 107]], [[50, 7], [8, 106]]]
# [[[57, 0], [4, 110]], [[40, 17], [13, 101]], [[43, 14], [14, 100]]]
# [[[57, 0], [5, 109]], [[41, 16], [10, 104]], [[45, 12], [13, 101]]]
# [[[56, 0], [3, 109]], [[43, 13], [18, 94]], [[37, 19], [11, 101]]]
# [[[57, 0], [5, 109]], [[38, 19], [9, 105]], [[48, 9], [14, 100]]]
# [[[57, 0], [3, 111]], [[39, 18], [9, 105]], [[46, 11], [17, 97]]]
# [[[57, 0], [6, 108]], [[39, 18], [6, 108]], [[48, 9], [15, 99]]]
# [[[57, 0], [4, 110]], [[43, 14], [18, 96]], [[39, 18], [10, 104]]]
# [[[56, 0], [7, 105]], [[35, 21], [7, 105]], [[45, 11], [18, 94]]]
# [[[57, 0], [3, 111]], [[36, 21], [9, 105]], [[48, 9], [18, 96]]]
# [[[57, 0], [9, 105]], [[39, 18], [8, 106]], [[46, 11], [12, 102]]]
# [[[57, 0], [2, 112]], [[42, 15], [11, 103]], [[45, 12], [14, 100]]]
# [[[57, 0], [2, 112]], [[39, 18], [17, 97]], [[40, 17], [16, 98]]]
# [[[56, 0], [4, 108]], [[45, 11], [13, 99]], [[43, 13], [7, 105]]]
# [[[57, 0], [6, 108]], [[40, 17], [10, 104]], [[46, 11], [12, 102]]]
# [[[57, 0], [1, 113]], [[45, 12], [15, 99]], [[42, 15], [11, 103]]]
# [[[57, 0], [9, 105]], [[38, 19], [10, 104]], [[45, 12], [12, 102]]]
# [[[57, 0], [5, 109]], [[39, 18], [10, 104]], [[46, 11], [14, 100]]]
# [[[56, 0], [1, 111]], [[36, 20], [9, 103]], [[47, 9], [19, 93]]]
# [[[57, 0], [6, 108]], [[40, 17], [8, 106]], [[48, 9], [12, 102]]]
# [[[57, 0], [6, 108]], [[39, 18], [9, 105]], [[47, 10], [13, 101]]]
# [[[57, 0], [0, 114]], [[35, 22], [8, 106]], [[49, 8], [22, 92]]]
# [[[57, 0], [5, 109]], [[42, 15], [9, 105]], [[47, 10], [11, 103]]]
# [[[56, 0], [5, 107]], [[39, 17], [11, 101]], [[44, 12], [13, 99]]]
# [[[57, 0], [4, 110]], [[36, 21], [11, 103]], [[45, 12], [18, 96]]]
# [[[57, 0], [3, 111]], [[38, 19], [4, 110]], [[52, 5], [17, 97]]]
# [[[57, 0], [4, 110]], [[45, 12], [13, 101]], [[43, 14], [9, 105]]]
# [[[57, 0], [6, 108]], [[35, 22], [5, 109]], [[51, 6], [17, 97]]]
# [[[56, 0], [4, 108]], [[35, 21], [13, 99]], [[43, 13], [17, 95]]]
# [[[57, 0], [5, 109]], [[38, 19], [15, 99]], [[41, 16], [15, 99]]]
# [[[57, 0], [4, 110]], [[35, 22], [8, 106]], [[49, 8], [18, 96]]]
# [[[57, 0], [5, 109]], [[32, 25], [6, 108]], [[51, 6], [20, 94]]]
# [[[57, 0], [2, 112]], [[46, 11], [11, 103]], [[45, 12], [10, 104]]]
# [[[56, 0], [6, 106]], [[35, 21], [8, 104]], [[46, 10], [17, 95]]]
# [[[57, 0], [1, 113]], [[38, 19], [7, 107]], [[49, 8], [19, 95]]]
# [[[57, 0], [6, 108]], [[41, 16], [7, 107]], [[49, 8], [11, 103]]]
# [[[57, 0], [9, 105]], [[35, 22], [14, 100]], [[42, 15], [14, 100]]]
# [[[57, 0], [1, 113]], [[41, 16], [10, 104]], [[47, 10], [15, 99]]]
# [[[56, 0], [9, 103]], [[35, 21], [8, 104]], [[44, 12], [16, 96]]]
# [[[57, 0], [4, 110]], [[40, 17], [8, 106]], [[48, 9], [14, 100]]]
# [[[57, 0], [8, 106]], [[36, 21], [7, 107]], [[47, 10], [16, 98]]]
# [[[57, 0], [3, 111]], [[41, 16], [10, 104]], [[45, 12], [15, 99]]]
# [[[57, 0], [8, 106]], [[38, 19], [16, 98]], [[39, 18], [13, 101]]]
# [[[56, 0], [3, 109]], [[39, 17], [11, 101]], [[45, 11], [14, 98]]]
# [[[57, 0], [10, 104]], [[38, 19], [14, 100]], [[40, 17], [12, 102]]]
# [[[57, 0], [1, 113]], [[39, 18], [7, 107]], [[50, 7], [17, 97]]]
# [[[57, 0], [5, 109]], [[38, 19], [10, 104]], [[47, 10], [14, 100]]]
# [[[57, 0], [2, 112]], [[43, 14], [9, 105]], [[46, 11], [14, 100]]]
# [[[56, 0], [4, 108]], [[40, 16], [6, 106]], [[50, 6], [12, 100]]]
# [[[57, 0], [4, 110]], [[36, 21], [11, 103]], [[45, 12], [18, 96]]]
# [[[57, 0], [6, 108]], [[37, 20], [11, 103]], [[45, 12], [15, 99]]]
# [[[57, 0], [4, 110]], [[42, 15], [8, 106]], [[48, 9], [12, 102]]]
# [[[57, 0], [7, 107]], [[37, 20], [11, 103]], [[42, 15], [17, 97]]]
# [[[56, 0], [3, 109]], [[45, 11], [10, 102]], [[45, 11], [9, 103]]]
# [[[57, 0], [6, 108]], [[45, 12], [14, 100]], [[41, 16], [8, 106]]]
# [[[57, 0], [14, 100]], [[27, 30], [9, 105]], [[42, 15], [22, 92]]]
# [[[57, 0], [1, 113]], [[41, 16], [9, 105]], [[48, 9], [15, 99]]]
# [[[57, 0], [2, 112]], [[37, 20], [9, 105]], [[48, 9], [18, 96]]]
# [[[56, 0], [6, 106]], [[47, 9], [9, 103]], [[46, 10], [4, 108]]]
# [[[57, 0], [2, 112]], [[39, 18], [9, 105]], [[47, 10], [17, 97]]]
# [[[57, 0], [7, 107]], [[40, 17], [11, 103]], [[45, 12], [11, 103]]]
# [[[57, 0], [9, 105]], [[36, 21], [13, 101]], [[43, 14], [13, 101]]]
# [[[57, 0], [0, 114]], [[42, 15], [12, 102]], [[45, 12], [15, 99]]]
# [[[56, 0], [4, 108]], [[38, 18], [9, 103]], [[46, 10], [15, 97]]]
# [[[57, 0], [6, 108]], [[39, 18], [14, 100]], [[40, 17], [15, 99]]]
# [[[57, 0], [4, 110]], [[41, 16], [3, 111]], [[53, 4], [13, 101]]]
# [[[57, 0], [4, 110]], [[37, 20], [13, 101]], [[44, 13], [16, 98]]]
# [[[57, 0], [3, 111]], [[42, 15], [9, 105]], [[47, 10], [13, 101]]]
# [[[56, 0], [6, 106]], [[31, 25], [11, 101]], [[44, 12], [20, 92]]]
# [[[57, 0], [4, 110]], [[34, 23], [6, 108]], [[51, 6], [19, 95]]]
# [[[57, 0], [5, 109]], [[41, 16], [12, 102]], [[44, 13], [12, 102]]]
# [[[57, 0], [8, 106]], [[41, 16], [14, 100]], [[41, 16], [10, 104]]]
# [[[57, 0], [3, 111]], [[38, 19], [7, 107]], [[49, 8], [17, 97]]]
# [[[56, 0], [0, 112]], [[37, 19], [8, 104]], [[48, 8], [19, 93]]]
# [[[57, 0], [4, 110]], [[44, 13], [6, 108]], [[47, 10], [13, 101]]]
# [[[57, 0], [4, 110]], [[34, 23], [11, 103]], [[46, 11], [19, 95]]]
# [[[57, 0], [5, 109]], [[43, 14], [14, 100]], [[42, 15], [10, 104]]]
# [[[57, 0], [8, 106]], [[36, 21], [12, 102]], [[44, 13], [14, 100]]]
# [[[56, 0], [3, 109]], [[36, 20], [8, 104]], [[48, 8], [17, 95]]]
# [[[57, 0], [6, 108]], [[37, 20], [13, 101]], [[43, 14], [15, 99]]]
# [[[57, 0], [6, 108]], [[41, 16], [9, 105]], [[47, 10], [11, 103]]]
# [[[57, 0], [3, 111]], [[40, 17], [5, 109]], [[51, 6], [15, 99]]]
# [[[57, 0], [3, 111]], [[46, 11], [12, 102]], [[45, 12], [8, 106]]]
# [[[56, 0], [3, 109]], [[38, 18], [6, 106]], [[49, 7], [16, 96]]]
# [[[57, 0], [6, 108]], [[39, 18], [14, 100]], [[41, 16], [14, 100]]]
# [[[57, 0], [4, 110]], [[42, 15], [7, 107]], [[49, 8], [12, 102]]]
# [[[57, 0], [4, 110]], [[40, 17], [7, 107]], [[50, 7], [13, 101]]]
# [[[57, 0], [3, 111]], [[42, 15], [11, 103]], [[45, 12], [13, 101]]]
# [[[56, 0], [5, 107]], [[35, 21], [6, 106]], [[48, 8], [18, 94]]]
# [[[57, 0], [3, 111]], [[42, 15], [8, 106]], [[49, 8], [12, 102]]]
# [[[57, 0], [6, 108]], [[35, 22], [10, 104]], [[46, 11], [17, 97]]]
# [[[57, 0], [2, 112]], [[40, 17], [8, 106]], [[48, 9], [16, 98]]]
# [[[57, 0], [4, 110]], [[36, 21], [12, 102]], [[45, 12], [17, 97]]]
# [[[56, 0], [5, 107]], [[45, 11], [8, 104]], [[46, 10], [8, 104]]]
# [[[57, 0], [3, 111]], [[39, 18], [14, 100]], [[43, 14], [15, 99]]]
# [[[57, 0], [8, 106]], [[40, 17], [8, 106]], [[48, 9], [10, 104]]]
# [[[57, 0], [4, 110]], [[35, 22], [11, 103]], [[42, 15], [22, 92]]]
# [[[57, 0], [7, 107]], [[36, 21], [8, 106]], [[46, 11], [17, 97]]]
# [[[56, 0], [4, 108]], [[41, 15], [9, 103]], [[46, 10], [12, 100]]]
# [[[57, 0], [3, 111]], [[44, 13], [7, 107]], [[49, 8], [11, 103]]]
# [[[57, 0], [7, 107]], [[37, 20], [15, 99]], [[39, 18], [16, 98]]]
# [[[57, 0], [6, 108]], [[39, 18], [8, 106]], [[48, 9], [13, 101]]]
# [[[57, 0], [4, 110]], [[41, 16], [9, 105]], [[48, 9], [12, 102]]]
# [[[56, 0], [4, 108]], [[35, 21], [13, 99]], [[43, 13], [17, 95]]]
# [[[57, 0], [6, 108]], [[39, 18], [7, 107]], [[48, 9], [14, 100]]]
# [[[57, 0], [8, 106]], [[43, 14], [16, 98]], [[39, 18], [8, 106]]]
# [[[57, 0], [2, 112]], [[38, 19], [8, 106]], [[48, 9], [18, 96]]]
# [[[57, 0], [3, 111]], [[38, 19], [10, 104]], [[46, 11], [17, 97]]]
# [[[56, 0], [2, 110]], [[40, 16], [7, 105]], [[49, 7], [14, 98]]]
# [[[57, 0], [5, 109]], [[39, 18], [14, 100]], [[42, 15], [14, 100]]]
# [[[57, 0], [2, 112]], [[42, 15], [12, 102]], [[44, 13], [14, 100]]]
# [[[57, 0], [5, 109]], [[33, 24], [12, 102]], [[45, 12], [19, 95]]]
# [[[57, 0], [9, 105]], [[41, 16], [9, 105]], [[47, 10], [8, 106]]]
# ...
# [[[23, 3], [5, 47]], [[17, 9], [4, 48]], [[24, 2], [5, 47]]]
# [[[26, 0], [6, 46]], [[15, 11], [2, 50]], [[23, 3], [6, 46]]]
# [[[26, 0], [8, 44]], [[15, 11], [2, 50]], [[23, 3], [4, 48]]]
# [[[27, 0], [5, 49]], [[19, 8], [1, 53]], [[26, 1], [3, 51]]]
# [[[26, 0], [7, 45]], [[16, 10], [0, 52]], [[24, 2], [5, 47]]]
# [[[26, 0], [6, 46]], [[14, 12], [1, 51]], [[24, 2], [7, 45]]]
# [[[26, 0], [5, 47]], [[12, 14], [0, 52]], [[26, 0], [9, 43]]]
# [[[26, 0], [6, 46]], [[11, 15], [3, 49]], [[23, 3], [9, 43]]]
# [[[27, 0], [6, 48]], [[15, 12], [0, 54]], [[27, 0], [6, 48]]]
# [[[26, 0], [5, 47]], [[15, 11], [2, 50]], [[23, 3], [7, 45]]]
# [[[26, 0], [5, 47]], [[15, 11], [2, 50]], [[24, 2], [6, 46]]]
# [[[26, 0], [8, 44]], [[11, 15], [3, 49]], [[21, 5], [9, 43]]]
# [[[26, 0], [7, 45]], [[14, 12], [3, 49]], [[22, 4], [6, 46]]]
# [[[27, 0], [7, 47]], [[13, 14], [1, 53]], [[26, 1], [7, 47]]]
# [[[26, 0], [9, 43]], [[12, 14], [0, 52]], [[23, 3], [8, 44]]]
# [[[26, 0], [3, 49]], [[19, 7], [2, 50]], [[24, 2], [4, 48]]]
# [[[26, 0], [8, 44]], [[13, 13], [0, 52]], [[26, 0], [5, 47]]]
# [[[26, 0], [3, 49]], [[15, 11], [1, 51]], [[25, 1], [8, 44]]]
# [[[27, 0], [4, 50]], [[16, 11], [2, 52]], [[25, 2], [7, 47]]]
# [[[26, 0], [7, 45]], [[11, 15], [2, 50]], [[23, 3], [9, 43]]]
# [[[26, 0], [3, 49]], [[18, 8], [0, 52]], [[26, 0], [5, 47]]]
# [[[26, 0], [7, 45]], [[13, 13], [0, 52]], [[26, 0], [6, 46]]]
# [[[26, 0], [6, 46]], [[16, 10], [2, 50]], [[22, 4], [6, 46]]]
# [[[27, 0], [11, 43]], [[9, 18], [0, 54]], [[25, 2], [9, 45]]]
# [[[26, 0], [10, 42]], [[13, 13], [2, 50]], [[21, 5], [6, 46]]]
# [[[26, 0], [4, 48]], [[18, 8], [0, 52]], [[24, 2], [6, 46]]]
# [[[26, 0], [5, 47]], [[15, 11], [6, 46]], [[19, 7], [7, 45]]]
# [[[26, 0], [5, 47]], [[15, 11], [0, 52]], [[26, 0], [6, 46]]]
# [[[27, 0], [6, 48]], [[15, 12], [0, 54]], [[27, 0], [6, 48]]]
# [[[26, 0], [4, 48]], [[14, 12], [0, 52]], [[26, 0], [8, 44]]]
# [[[26, 0], [7, 45]], [[15, 11], [1, 51]], [[23, 3], [6, 46]]]
# [[[26, 0], [7, 45]], [[8, 18], [1, 51]], [[25, 1], [11, 41]]]
# [[[24, 2], [4, 48]], [[19, 7], [4, 48]], [[24, 2], [3, 49]]]
# [[[27, 0], [15, 39]], [[7, 20], [1, 53]], [[24, 3], [7, 47]]]
# [[[26, 0], [3, 49]], [[20, 6], [3, 49]], [[23, 3], [3, 49]]]
# [[[24, 2], [3, 49]], [[17, 9], [3, 49]], [[25, 1], [6, 46]]]
# [[[26, 0], [5, 47]], [[11, 15], [2, 50]], [[23, 3], [11, 41]]]
# [[[26, 0], [6, 46]], [[12, 14], [0, 52]], [[26, 0], [8, 44]]]
# [[[27, 0], [4, 50]], [[15, 12], [0, 54]], [[27, 0], [8, 46]]]
# [[[26, 0], [7, 45]], [[13, 13], [1, 51]], [[24, 2], [7, 45]]]
# [[[26, 0], [6, 46]], [[17, 9], [1, 51]], [[24, 2], [4, 48]]]
# [[[26, 0], [5, 47]], [[15, 11], [2, 50]], [[24, 2], [6, 46]]]
# [[[26, 0], [6, 46]], [[15, 11], [1, 51]], [[25, 1], [5, 47]]]
# [[[27, 0], [13, 41]], [[13, 14], [2, 52]], [[21, 6], [5, 49]]]
# [[[26, 0], [10, 42]], [[11, 15], [0, 52]], [[25, 1], [6, 46]]]
# [[[26, 0], [4, 48]], [[15, 11], [0, 52]], [[24, 2], [9, 43]]]
# [[[26, 0], [5, 47]], [[17, 9], [0, 52]], [[25, 1], [5, 47]]]
# [[[26, 0], [6, 46]], [[14, 12], [0, 52]], [[26, 0], [6, 46]]]
# [[[27, 0], [6, 48]], [[13, 14], [2, 52]], [[25, 2], [8, 46]]]
# [[[26, 0], [7, 45]], [[16, 10], [1, 51]], [[25, 1], [3, 49]]]
# [[[26, 0], [6, 46]], [[11, 15], [0, 52]], [[25, 1], [10, 42]]]
# [[[26, 0], [7, 45]], [[18, 8], [0, 52]], [[24, 2], [3, 49]]]
# [[[26, 0], [7, 45]], [[13, 13], [1, 51]], [[25, 1], [6, 46]]]
# [[[27, 0], [6, 48]], [[16, 11], [1, 53]], [[26, 1], [5, 49]]]
# [[[26, 0], [8, 44]], [[11, 15], [1, 51]], [[23, 3], [9, 43]]]
# [[[26, 0], [8, 44]], [[14, 12], [1, 51]], [[25, 1], [4, 48]]]
# [[[26, 0], [4, 48]], [[17, 9], [2, 50]], [[23, 3], [6, 46]]]
# [[[26, 0], [6, 46]], [[16, 10], [0, 52]], [[24, 2], [6, 46]]]
# [[[27, 0], [8, 46]], [[13, 14], [3, 51]], [[23, 4], [7, 47]]]
# [[[26, 0], [4, 48]], [[13, 13], [1, 51]], [[24, 2], [10, 42]]]
# [[[26, 0], [6, 46]], [[17, 9], [2, 50]], [[23, 3], [4, 48]]]
# [[[26, 0], [8, 44]], [[12, 14], [0, 52]], [[26, 0], [6, 46]]]
# [[[26, 0], [5, 47]], [[18, 8], [4, 48]], [[20, 6], [5, 47]]]
# [[[27, 0], [6, 48]], [[14, 13], [2, 52]], [[25, 2], [7, 47]]]
# [[[26, 0], [7, 45]], [[16, 10], [2, 50]], [[21, 5], [6, 46]]]
# [[[26, 0], [6, 46]], [[15, 11], [2, 50]], [[24, 2], [5, 47]]]
# [[[26, 0], [5, 47]], [[14, 12], [3, 49]], [[22, 4], [8, 44]]]
# [[[26, 0], [8, 44]], [[14, 12], [1, 51]], [[24, 2], [5, 47]]]
# [[[27, 0], [10, 44]], [[14, 13], [1, 53]], [[24, 3], [5, 49]]]
# [[[26, 0], [2, 50]], [[17, 9], [0, 52]], [[26, 0], [7, 45]]]
# [[[26, 0], [5, 47]], [[15, 11], [0, 52]], [[26, 0], [6, 46]]]
# [[[26, 0], [7, 45]], [[14, 12], [3, 49]], [[21, 5], [7, 45]]]
# [[[26, 0], [10, 42]], [[15, 11], [1, 51]], [[24, 2], [2, 50]]]
# [[[27, 0], [7, 47]], [[15, 12], [0, 54]], [[27, 0], [5, 49]]]
# [[[24, 2], [4, 48]], [[14, 12], [2, 50]], [[26, 0], [8, 44]]]
# [[[26, 0], [3, 49]], [[19, 7], [3, 49]], [[23, 3], [4, 48]]]
# [[[26, 0], [5, 47]], [[17, 9], [2, 50]], [[23, 3], [5, 47]]]
# [[[26, 0], [9, 43]], [[11, 15], [1, 51]], [[23, 3], [8, 44]]]
# [[[25, 2], [3, 51]], [[14, 13], [4, 50]], [[25, 2], [10, 44]]]
# [[[26, 0], [9, 43]], [[11, 15], [2, 50]], [[23, 3], [7, 45]]]
# [[[26, 0], [7, 45]], [[18, 8], [1, 51]], [[22, 4], [4, 48]]]
# [[[26, 0], [4, 48]], [[16, 10], [0, 52]], [[26, 0], [6, 46]]]
# [[[26, 0], [8, 44]], [[17, 9], [2, 50]], [[24, 2], [1, 51]]]
# [[[27, 0], [12, 42]], [[13, 14], [0, 54]], [[26, 1], [3, 51]]]
# [[[26, 0], [1, 51]], [[18, 8], [0, 52]], [[26, 0], [7, 45]]]
# [[[26, 0], [7, 45]], [[14, 12], [0, 52]], [[26, 0], [5, 47]]]
# [[[26, 0], [5, 47]], [[15, 11], [0, 52]], [[26, 0], [6, 46]]]
# [[[26, 0], [3, 49]], [[15, 11], [5, 47]], [[21, 5], [8, 44]]]
# [[[27, 0], [6, 48]], [[15, 12], [0, 54]], [[27, 0], [6, 48]]]
# [[[26, 0], [10, 42]], [[12, 14], [2, 50]], [[21, 5], [7, 45]]]
# [[[26, 0], [5, 47]], [[13, 13], [1, 51]], [[25, 1], [8, 44]]]
# [[[26, 0], [6, 46]], [[14, 12], [0, 52]], [[24, 2], [8, 44]]]
# [[[26, 0], [6, 46]], [[17, 9], [3, 49]], [[23, 3], [3, 49]]]
# [[[27, 0], [4, 50]], [[18, 9], [2, 52]], [[25, 2], [5, 49]]]
# [[[24, 2], [7, 45]], [[16, 10], [5, 47]], [[22, 4], [4, 48]]]
# [[[26, 0], [5, 47]], [[12, 14], [0, 52]], [[26, 0], [9, 43]]]
# [[[26, 0], [4, 48]], [[13, 13], [5, 47]], [[21, 5], [9, 43]]]
# [[[23, 3], [12, 40]], [[13, 13], [0, 52]], [[24, 2], [6, 46]]]
# [[[27, 0], [10, 44]], [[13, 14], [4, 50]], [[22, 5], [5, 49]]]
# [[[26, 0], [2, 50]], [[18, 8], [2, 50]], [[24, 2], [6, 46]]]
# [[[26, 0], [6, 46]], [[13, 13], [0, 52]], [[26, 0], [7, 45]]]
# [[[26, 0], [7, 45]], [[18, 8], [5, 47]], [[19, 7], [3, 49]]]
# [[[26, 0], [4, 48]], [[14, 12], [0, 52]], [[25, 1], [9, 43]]]
# [[[27, 0], [8, 46]], [[10, 17], [2, 52]], [[25, 2], [9, 45]]]
# [[[23, 3], [6, 46]], [[16, 10], [5, 47]], [[23, 3], [5, 47]]]
# [[[26, 0], [6, 46]], [[14, 12], [2, 50]], [[24, 2], [6, 46]]]
# [[[26, 0], [4, 48]], [[16, 10], [0, 52]], [[26, 0], [6, 46]]]
# [[[24, 2], [6, 46]], [[15, 11], [2, 50]], [[24, 2], [7, 45]]]
# [[[27, 0], [4, 50]], [[17, 10], [0, 54]], [[27, 0], [6, 48]]]
# [[[26, 0], [4, 48]], [[16, 10], [0, 52]], [[25, 1], [7, 45]]]
# [[[26, 0], [8, 44]], [[11, 15], [1, 51]], [[25, 1], [7, 45]]]
# [[[26, 0], [5, 47]], [[16, 10], [1, 51]], [[25, 1], [5, 47]]]
# [[[26, 0], [8, 44]], [[16, 10], [3, 49]], [[22, 4], [3, 49]]]
# [[[27, 0], [5, 49]], [[15, 12], [2, 52]], [[25, 2], [7, 47]]]
# [[[26, 0], [7, 45]], [[15, 11], [3, 49]], [[21, 5], [6, 46]]]
# [[[26, 0], [11, 41]], [[10, 16], [1, 51]], [[25, 1], [5, 47]]]
# [[[26, 0], [6, 46]], [[16, 10], [3, 49]], [[22, 4], [5, 47]]]
# [[[26, 0], [5, 47]], [[15, 11], [0, 52]], [[25, 1], [7, 45]]]
# [[[27, 0], [6, 48]], [[16, 11], [3, 51]], [[23, 4], [6, 48]]]
# [[[26, 0], [8, 44]], [[11, 15], [1, 51]], [[24, 2], [8, 44]]]
# [[[26, 0], [1, 51]], [[18, 8], [2, 50]], [[24, 2], [7, 45]]]
# [[[26, 0], [8, 44]], [[16, 10], [1, 51]], [[25, 1], [2, 50]]]
# [[[26, 0], [9, 43]], [[11, 15], [0, 52]], [[24, 2], [8, 44]]]
# [[[27, 0], [12, 42]], [[12, 15], [0, 54]], [[25, 2], [5, 49]]]
# [[[26, 0], [8, 44]], [[15, 11], [4, 48]], [[20, 6], [5, 47]]]
# [[[26, 0], [5, 47]], [[18, 8], [0, 52]], [[25, 1], [4, 48]]]
# [[[26, 0], [5, 47]], [[13, 13], [4, 48]], [[22, 4], [8, 44]]]
# [[[26, 0], [6, 46]], [[13, 13], [1, 51]], [[25, 1], [7, 45]]]
# [[[27, 0], [5, 49]], [[17, 10], [1, 53]], [[26, 1], [5, 49]]]
# [[[26, 0], [4, 48]], [[16, 10], [2, 50]], [[24, 2], [6, 46]]]
# [[[26, 0], [10, 42]], [[14, 12], [2, 50]], [[22, 4], [4, 48]]]
# [[[26, 0], [6, 46]], [[9, 17], [0, 52]], [[24, 2], [13, 39]]]
# [[[26, 0], [7, 45]], [[17, 9], [4, 48]], [[20, 6], [4, 48]]]
# [[[25, 2], [10, 44]], [[14, 13], [4, 50]], [[24, 3], [4, 50]]]
# [[[26, 0], [5, 47]], [[16, 10], [2, 50]], [[24, 2], [5, 47]]]
# [[[26, 0], [7, 45]], [[11, 15], [3, 49]], [[23, 3], [8, 44]]]
# [[[26, 0], [3, 49]], [[15, 11], [0, 52]], [[25, 1], [9, 43]]]
# [[[26, 0], [6, 46]], [[18, 8], [0, 52]], [[24, 2], [4, 48]]]
# [[[27, 0], [7, 47]], [[15, 12], [0, 54]], [[26, 1], [6, 48]]]
# [[[26, 0], [5, 47]], [[14, 12], [1, 51]], [[25, 1], [7, 45]]]
# [[[26, 0], [4, 48]], [[14, 12], [3, 49]], [[23, 3], [8, 44]]]
# [[[26, 0], [5, 47]], [[11, 15], [4, 48]], [[22, 4], [10, 42]]]
# [[[26, 0], [6, 46]], [[16, 10], [2, 50]], [[24, 2], [4, 48]]]
# [[[27, 0], [7, 47]], [[16, 11], [1, 53]], [[26, 1], [4, 50]]]
# [[[26, 0], [6, 46]], [[19, 7], [2, 50]], [[23, 3], [2, 50]]]
# [[[26, 0], [5, 47]], [[13, 13], [0, 52]], [[26, 0], [8, 44]]]
# [[[26, 0], [5, 47]], [[14, 12], [1, 51]], [[24, 2], [8, 44]]]
# [[[26, 0], [10, 42]], [[12, 14], [1, 51]], [[22, 4], [7, 45]]]
# [[[25, 2], [5, 49]], [[17, 10], [3, 51]], [[26, 1], [5, 49]]]
# [[[26, 0], [5, 47]], [[15, 11], [3, 49]], [[23, 3], [6, 46]]]
# [[[26, 0], [5, 47]], [[14, 12], [1, 51]], [[25, 1], [7, 45]]]
# [[[26, 0], [11, 41]], [[13, 13], [0, 52]], [[24, 2], [4, 48]]]
# [[[26, 0], [3, 49]], [[11, 15], [4, 48]], [[22, 4], [12, 40]]]
# [[[27, 0], [6, 48]], [[14, 13], [1, 53]], [[26, 1], [7, 47]]]
# [[[26, 0], [4, 48]], [[18, 8], [1, 51]], [[25, 1], [4, 48]]]
# [[[26, 0], [7, 45]], [[11, 15], [0, 52]], [[25, 1], [9, 43]]]
# [[[26, 0], [5, 47]], [[12, 14], [1, 51]], [[25, 1], [9, 43]]]
# [[[26, 0], [10, 42]], [[12, 14], [2, 50]], [[23, 3], [5, 47]]]
# [[[25, 2], [6, 48]], [[16, 11], [3, 51]], [[24, 3], [7, 47]]]
# [[[26, 0], [8, 44]], [[13, 13], [0, 52]], [[26, 0], [5, 47]]]
# [[[26, 0], [4, 48]], [[16, 10], [0, 52]], [[26, 0], [6, 46]]]
# [[[26, 0], [4, 48]], [[12, 14], [0, 52]], [[26, 0], [10, 42]]]
# [[[26, 0], [8, 44]], [[13, 13], [4, 48]], [[22, 4], [5, 47]]]
# [[[27, 0], [9, 45]], [[15, 12], [1, 53]], [[25, 2], [4, 50]]]
# [[[26, 0], [6, 46]], [[11, 15], [3, 49]], [[22, 4], [10, 42]]]
# [[[26, 0], [5, 47]], [[15, 11], [1, 51]], [[24, 2], [7, 45]]]
# [[[26, 0], [5, 47]], [[18, 8], [0, 52]], [[26, 0], [3, 49]]]
# [[[26, 0], [4, 48]], [[15, 11], [3, 49]], [[23, 3], [7, 45]]]
# [[[27, 0], [9, 45]], [[14, 13], [3, 51]], [[24, 3], [4, 50]]]
# [[[26, 0], [3, 49]], [[13, 13], [1, 51]], [[25, 1], [10, 42]]]
# [[[26, 0], [7, 45]], [[18, 8], [0, 52]], [[24, 2], [3, 49]]]
# [[[26, 0], [8, 44]], [[12, 14], [3, 49]], [[22, 4], [7, 45]]]
# [[[26, 0], [6, 46]], [[13, 13], [2, 50]], [[24, 2], [7, 45]]]
# [[[27, 0], [6, 48]], [[17, 10], [2, 52]], [[25, 2], [4, 50]]]
# [[[26, 0], [9, 43]], [[10, 16], [3, 49]], [[20, 6], [10, 42]]]
# [[[26, 0], [6, 46]], [[13, 13], [2, 50]], [[24, 2], [7, 45]]]
# [[[26, 0], [9, 43]], [[16, 10], [0, 52]], [[24, 2], [3, 49]]]
# [[[26, 0], [6, 46]], [[12, 14], [1, 51]], [[25, 1], [8, 44]]]
# [[[27, 0], [6, 48]], [[17, 10], [3, 51]], [[23, 4], [5, 49]]]
# [[[26, 0], [5, 47]], [[16, 10], [0, 52]], [[24, 2], [7, 45]]]
# [[[26, 0], [6, 46]], [[15, 11], [2, 50]], [[23, 3], [6, 46]]]
# [[[24, 2], [12, 40]], [[10, 16], [3, 49]], [[23, 3], [6, 46]]]
# [[[26, 0], [5, 47]], [[14, 12], [2, 50]], [[24, 2], [7, 45]]]
# [[[27, 0], [9, 45]], [[14, 13], [1, 53]], [[26, 1], [4, 50]]]
# [[[26, 0], [7, 45]], [[15, 11], [1, 51]], [[24, 2], [5, 47]]]
# [[[26, 0], [2, 50]], [[18, 8], [4, 48]], [[22, 4], [6, 46]]]
# [[[26, 0], [11, 41]], [[13, 13], [2, 50]], [[20, 6], [6, 46]]]
# [[[26, 0], [5, 47]], [[13, 13], [1, 51]], [[24, 2], [9, 43]]]
# [[[27, 0], [6, 48]], [[14, 13], [0, 54]], [[27, 0], [7, 47]]]
# [[[26, 0], [7, 45]], [[15, 11], [1, 51]], [[24, 2], [5, 47]]]
# [[[26, 0], [9, 43]], [[15, 11], [1, 51]], [[24, 2], [3, 49]]]
# [[[26, 0], [4, 48]], [[11, 15], [3, 49]], [[23, 3], [11, 41]]]
# [[[24, 2], [6, 46]], [[16, 10], [4, 48]], [[21, 5], [7, 45]]]
# [[[27, 0], [6, 48]], [[17, 10], [3, 51]], [[21, 6], [7, 47]]]
# [[[26, 0], [11, 41]], [[10, 16], [1, 51]], [[22, 4], [8, 44]]]
# [[[26, 0], [3, 49]], [[19, 7], [0, 52]], [[26, 0], [4, 48]]]
# [[[26, 0], [7, 45]], [[13, 13], [0, 52]], [[24, 2], [8, 44]]]
# [[[26, 0], [9, 43]], [[14, 12], [0, 52]], [[26, 0], [3, 49]]]
# [[[27, 0], [6, 48]], [[15, 12], [1, 53]], [[26, 1], [6, 48]]]
# [[[26, 0], [7, 45]], [[14, 12], [1, 51]], [[23, 3], [7, 45]]]
# [[[26, 0], [7, 45]], [[16, 10], [0, 52]], [[26, 0], [3, 49]]]
# [[[26, 0], [7, 45]], [[16, 10], [2, 50]], [[22, 4], [5, 47]]]
# [[[26, 0], [6, 46]], [[12, 14], [3, 49]], [[22, 4], [9, 43]]]
# [[[27, 0], [11, 43]], [[10, 17], [2, 52]], [[25, 2], [6, 48]]]
# [[[26, 0], [5, 47]], [[16, 10], [4, 48]], [[21, 5], [6, 46]]]
# [[[26, 0], [2, 50]], [[18, 8], [0, 52]], [[25, 1], [7, 45]]]
# [[[26, 0], [2, 50]], [[15, 11], [2, 50]], [[23, 3], [10, 42]]]
# [[[23, 3], [10, 42]], [[13, 13], [6, 46]], [[23, 3], [3, 49]]]
# [[[27, 0], [7, 47]], [[14, 13], [3, 51]], [[24, 3], [6, 48]]]
# [[[26, 0], [5, 47]], [[16, 10], [0, 52]], [[26, 0], [5, 47]]]
# [[[26, 0], [6, 46]], [[13, 13], [0, 52]], [[25, 1], [8, 44]]]
# [[[26, 0], [4, 48]], [[14, 12], [1, 51]], [[25, 1], [8, 44]]]
# [[[26, 0], [4, 48]], [[17, 9], [1, 51]], [[25, 1], [5, 47]]]
# [[[27, 0], [7, 47]], [[13, 14], [0, 54]], [[27, 0], [7, 47]]]
# [[[26, 0], [7, 45]], [[13, 13], [0, 52]], [[25, 1], [7, 45]]]
# [[[26, 0], [8, 44]], [[15, 11], [3, 49]], [[21, 5], [5, 47]]]
# [[[23, 3], [7, 45]], [[12, 14], [4, 48]], [[25, 1], [7, 45]]]
# [[[26, 0], [7, 45]], [[16, 10], [3, 49]], [[21, 5], [5, 47]]]
# [[[27, 0], [5, 49]], [[16, 11], [5, 49]], [[21, 6], [7, 47]]]
# [[[26, 0], [10, 42]], [[12, 14], [2, 50]], [[24, 2], [4, 48]]]
# [[[26, 0], [3, 49]], [[14, 12], [0, 52]], [[26, 0], [9, 43]]]
# [[[26, 0], [8, 44]], [[15, 11], [0, 52]], [[24, 2], [5, 47]]]
# [[[26, 0], [8, 44]], [[14, 12], [2, 50]], [[22, 4], [6, 46]]]
# [[[27, 0], [10, 44]], [[13, 14], [1, 53]], [[25, 2], [5, 49]]]
# [[[26, 0], [4, 48]], [[17, 9], [3, 49]], [[23, 3], [5, 47]]]
# [[[26, 0], [6, 46]], [[18, 8], [3, 49]], [[20, 6], [5, 47]]]
# [[[26, 0], [7, 45]], [[11, 15], [4, 48]], [[22, 4], [8, 44]]]
# [[[26, 0], [6, 46]], [[14, 12], [2, 50]], [[23, 3], [7, 45]]]
# [[[27, 0], [6, 48]], [[15, 12], [0, 54]], [[27, 0], [6, 48]]]
# [[[26, 0], [6, 46]], [[11, 15], [1, 51]], [[24, 2], [10, 42]]]
# [[[26, 0], [7, 45]], [[13, 13], [0, 52]], [[25, 1], [7, 45]]]
# [[[26, 0], [7, 45]], [[16, 10], [0, 52]], [[26, 0], [3, 49]]]
# [[[26, 0], [4, 48]], [[18, 8], [3, 49]], [[23, 3], [4, 48]]]
# [[[27, 0], [4, 50]], [[13, 14], [3, 51]], [[24, 3], [10, 44]]]
# [[[26, 0], [8, 44]], [[15, 11], [1, 51]], [[23, 3], [5, 47]]]
# [[[26, 0], [7, 45]], [[9, 17], [0, 52]], [[26, 0], [10, 42]]]
# [[[26, 0], [6, 46]], [[17, 9], [0, 52]], [[26, 0], [3, 49]]]
# [[[26, 0], [3, 49]], [[19, 7], [1, 51]], [[24, 2], [5, 47]]]
# [[[27, 0], [9, 45]], [[14, 13], [1, 53]], [[24, 3], [6, 48]]]
# [[[26, 0], [9, 43]], [[15, 11], [1, 51]], [[24, 2], [3, 49]]]
# [[[26, 0], [7, 45]], [[11, 15], [2, 50]], [[22, 4], [10, 42]]]
# [[[26, 0], [6, 46]], [[15, 11], [1, 51]], [[25, 1], [5, 47]]]
# [[[26, 0], [6, 46]], [[13, 13], [1, 51]], [[23, 3], [9, 43]]]
# [[[27, 0], [2, 52]], [[21, 6], [1, 53]], [[26, 1], [4, 50]]]
# [[[26, 0], [9, 43]], [[11, 15], [4, 48]], [[21, 5], [7, 45]]]
# [[[26, 0], [5, 47]], [[17, 9], [1, 51]], [[25, 1], [4, 48]]]
# [[[26, 0], [8, 44]], [[15, 11], [0, 52]], [[24, 2], [5, 47]]]
# [[[26, 0], [6, 46]], [[12, 14], [4, 48]], [[22, 4], [8, 44]]]
# [[[27, 0], [5, 49]], [[14, 13], [1, 53]], [[26, 1], [8, 46]]]
# [[[26, 0], [3, 49]], [[18, 8], [2, 50]], [[24, 2], [5, 47]]]
# [[[26, 0], [9, 43]], [[18, 8], [0, 52]], [[24, 2], [1, 51]]]
# [[[26, 0], [5, 47]], [[13, 13], [1, 51]], [[25, 1], [8, 44]]]
# [[[26, 0], [7, 45]], [[13, 13], [0, 52]], [[25, 1], [7, 45]]]
# [[[25, 2], [5, 49]], [[14, 13], [2, 52]], [[27, 0], [8, 46]]]
# [[[26, 0], [5, 47]], [[16, 10], [1, 51]], [[25, 1], [5, 47]]]
# [[[26, 0], [7, 45]], [[14, 12], [3, 49]], [[21, 5], [7, 45]]]
# [[[26, 0], [10, 42]], [[14, 12], [0, 52]], [[23, 3], [5, 47]]]
# [[[26, 0], [6, 46]], [[15, 11], [2, 50]], [[24, 2], [5, 47]]]

# %% [markdown]
# ### 4a) Test Accuracy Scores

# %%
df_acc_res = get_all_scores(res_dict, 'full_test_accs')
df_acc_res.boxplot(by='model', figsize=(12,12), showmeans = True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001BFD0223908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BFD14955C0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BFD13ED668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BFD12E8E10>]],
#       dtype=object)

# %% [markdown]
# ### 4b) Information Gain

# %%
df_null_res = get_all_scores(res_dict, 'full_test_null_accs')

dict_res_test_ig = {}
dict_res_test_ig['model'] = df_acc_res['model']
for user in all_users[1:5]:
    test_ig = [df_acc_res[user][pos] - df_null_res[user][pos] for pos in range(len(df_acc_res))]
    dict_res_test_ig[user] = test_ig

df_test_ig = pd.DataFrame(dict_res_test_ig)

# %%
df_test_ig.boxplot(by='model', figsize=(12,12), showmeans = True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022383267908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022383325B38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002238325A9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022383679D68>]],
#       dtype=object)
